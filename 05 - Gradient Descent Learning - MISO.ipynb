# %%
# Out:
# =================== Iteration: 1
# input             : 20
# expected_value    : 180
#
# weight            : 7
# prediction        : 140
#
# error             : 1600
# error (round)     : 1600
# error_derivative  : -1600
#
# learning_rate     : 0.01
# weight_adjustment : -16.0
# weight_new        : 23.0
#
# =================== Iteration: 2
# input             : 20
# expected_value    : 180
#
# weight            : 23.0
# prediction        : 460.0
#
# error             : 78400.0
# error (round)     : 78400.0
# error_derivative  : 11200.0
#
# learning_rate     : 0.01
# weight_adjustment : 112.0
# weight_new        : -89.0
#
# =================== Iteration: 3
# input             : 20
# expected_value    : 180
#
# weight            : -89.0
# prediction        : -1780.0
#
# error             : 3841600.0
# error (round)     : 3841600.0
# error_derivative  : -78400.0
#
# learning_rate     : 0.01
# weight_adjustment : -784.0
# weight_new        : 695.0
#
# =================== Iteration: 4
# ...
