# %%
MAX_ITERATION = 100
MINUTES_RUNNING = 20
ACTUAL_CALORIES_BURNED = 180
INITIAL_WEIGHT = 7

SLOW_LEARNING_RATE = 0.1            # 21 iterations
FASTEST_LEARNING_RATE = 2           # Only 2 iterations
OSCILLATING_LEARNING_RATE = 3       # > 100 iterations

learning_rate = SLOW_LEARNING_RATE


def neural_network(input, weight):
    predicted_value = input * weight
    return predicted_value


input = MINUTES_RUNNING
expected_value = ACTUAL_CALORIES_BURNED
weight = INITIAL_WEIGHT
iteration = 1

while True:
    prediction = neural_network(input, weight)
    error = (prediction - ACTUAL_CALORIES_BURNED) ** 2

    weight_upward = weight + learning_rate
    prediction_upward = neural_network(input, weight_upward)
    error_upward = (prediction_upward - ACTUAL_CALORIES_BURNED) ** 2

    weight_downwards = weight - learning_rate
    prediction_downwards = neural_network(input, weight_downwards)
    error_downwards = (prediction_downwards - ACTUAL_CALORIES_BURNED) ** 2

    print(f"======================== Iteration: {iteration}")
    print(f"weight                 : {weight}")
    print(f"prediction             : {prediction}")
    print(f"error                  : {error}")
    print(f"error (round)          : {round(error, 5)} {"     ===> Yeayyyy the error is zero !!!!" if round(error, 5) == 0 else ""}")
    print()
    print(f"weight_upward          : {weight_upward}")
    print(f"prediction_upward      : {prediction_upward}")
    print(f"error_upward           : {error_upward}")
    print(f"error_upward (round)   : {round(error_upward, 5)}")
    print()
    print(f"weight_downwards       : {weight_downwards}")
    print(f"prediction_downwards   : {prediction_downwards}")
    print(f"error_downwards        : {error_downwards}")
    print(f"error_downwards (round): {round(error_downwards, 5)}")
    print()


    iteration += 1
    if(round(error, 5) == 0 or iteration > MAX_ITERATION):
        break

    if(error_upward < error_downwards):
        weight = weight_upward
        print(f"new weight using weight_upward: {weight}\n")
    else:
        weight = weight_downwards
        print(f"new weight using weight_downward: {weight}\n")
# Out:
# ======================== Iteration: 1
# weight                 : 7
# prediction             : 140
# error                  : 1600
# error (round)          : 1600
#
# weight_upward          : 7.01
# prediction_upward      : 140.2
# error_upward           : 1584.0400000000009
# error_upward (round)   : 1584.04
#
# weight_downwards       : 6.99
# prediction_downwards   : 139.8
# error_downwards        : 1616.039999999999
# error_downwards (round): 1616.04
#
# new weight using weight_upward: 7.01
#
# ======================== Iteration: 2
# weight                 : 7.01
# prediction             : 140.2
# error                  : 1584.0400000000009
# error (round)          : 1584.04
#
# weight_upward          : 7.02
# prediction_upward      : 140.39999999999998
# error_upward           : 1568.160000000002
# error_upward (round)   : 1568.16
#
# weight_downwards       : 7.0
# prediction_downwards   : 140.0
# error_downwards        : 1600.0
# error_downwards (round): 1600.0
#
# new weight using weight_upward: 7.02
#
# ======================== Iteration: 3
# weight                 : 7.02
# prediction             : 140.39999999999998
# error                  : 1568.160000000002
# error (round)          : 1568.16
#
# weight_upward          : 7.029999999999999
# prediction_upward      : 140.6
# error_upward           : 1552.3600000000004
# error_upward (round)   : 1552.36
#
# weight_downwards       : 7.01
# prediction_downwards   : 140.2
# error_downwards        : 1584.0400000000009
# error_downwards (round): 1584.04
#
# new weight using weight_upward: 7.029999999999999
#
# ======================== Iteration: 4
# weight                 : 7.029999999999999
# prediction             : 140.6
# error                  : 1552.3600000000004
# error (round)          : 1552.36
#
# weight_upward          : 7.039999999999999
# prediction_upward      : 140.79999999999998
# error_upward           : 1536.6400000000012
# error_upward (round)   : 1536.64
#
# weight_downwards       : 7.02
# prediction_downwards   : 140.39999999999998
# error_downwards        : 1568.160000000002
# error_downwards (round): 1568.16
#
# new weight using weight_upward: 7.039999999999999
#
# ======================== Iteration: 5
# weight                 : 7.039999999999999
# prediction             : 140.79999999999998
# error                  : 1536.6400000000012
# error (round)          : 1536.64
#
# weight_upward          : 7.049999999999999
# prediction_upward      : 140.99999999999997
# error_upward           : 1521.0000000000023
# error_upward (round)   : 1521.0
#
# weight_downwards       : 7.029999999999999
# prediction_downwards   : 140.6
# error_downwards        : 1552.3600000000004
# error_downwards (round): 1552.36
#
# new weight using weight_upward: 7.049999999999999
#
# ======================== Iteration: 6
# weight                 : 7.049999999999999
# prediction             : 140.99999999999997
# error                  : 1521.0000000000023
# error (round)          : 1521.0
#
# weight_upward          : 7.059999999999999
# prediction_upward      : 141.2
# error_upward           : 1505.440000000001
# error_upward (round)   : 1505.44
#
# weight_downwards       : 7.039999999999999
# prediction_downwards   : 140.79999999999998
# error_downwards        : 1536.6400000000012
# error_downwards (round): 1536.64
#
# new weight using weight_upward: 7.059999999999999
#
# ======================== Iteration: 7
# weight                 : 7.059999999999999
# prediction             : 141.2
# error                  : 1505.440000000001
# error (round)          : 1505.44
#
# weight_upward          : 7.0699999999999985
# prediction_upward      : 141.39999999999998
# error_upward           : 1489.9600000000019
# error_upward (round)   : 1489.96
#
# weight_downwards       : 7.049999999999999
# prediction_downwards   : 140.99999999999997
# error_downwards        : 1521.0000000000023
# error_downwards (round): 1521.0
#
# new weight using weight_upward: 7.0699999999999985
#
# ======================== Iteration: 8
# weight                 : 7.0699999999999985
# prediction             : 141.39999999999998
# error                  : 1489.9600000000019
# error (round)          : 1489.96
#
# weight_upward          : 7.079999999999998
# prediction_upward      : 141.59999999999997
# error_upward           : 1474.5600000000027
# error_upward (round)   : 1474.56
#
# weight_downwards       : 7.059999999999999
# prediction_downwards   : 141.2
# error_downwards        : 1505.440000000001
# error_downwards (round): 1505.44
#
# new weight using weight_upward: 7.079999999999998
#
# ======================== Iteration: 9
# weight                 : 7.079999999999998
# prediction             : 141.59999999999997
# error                  : 1474.5600000000027
# error (round)          : 1474.56
#
# weight_upward          : 7.089999999999998
# prediction_upward      : 141.79999999999995
# error_upward           : 1459.2400000000034
# error_upward (round)   : 1459.24
#
# weight_downwards       : 7.0699999999999985
# prediction_downwards   : 141.39999999999998
# error_downwards        : 1489.9600000000019
# error_downwards (round): 1489.96
#
# new weight using weight_upward: 7.089999999999998
#
# ======================== Iteration: 10
# weight                 : 7.089999999999998
# prediction             : 141.79999999999995
# error                  : 1459.2400000000034
# error (round)          : 1459.24
#
# weight_upward          : 7.099999999999998
# prediction_upward      : 141.99999999999994
# error_upward           : 1444.0000000000043
# error_upward (round)   : 1444.0
#
# weight_downwards       : 7.079999999999998
# prediction_downwards   : 141.59999999999997
# error_downwards        : 1474.5600000000027
# error_downwards (round): 1474.56
#
# new weight using weight_upward: 7.099999999999998
#
# ======================== Iteration: 11
# weight                 : 7.099999999999998
# prediction             : 141.99999999999994
# error                  : 1444.0000000000043
# error (round)          : 1444.0
#
# weight_upward          : 7.109999999999998
# prediction_upward      : 142.19999999999996
# error_upward           : 1428.840000000003
# error_upward (round)   : 1428.84
#
# weight_downwards       : 7.089999999999998
# prediction_downwards   : 141.79999999999995
# error_downwards        : 1459.2400000000034
# error_downwards (round): 1459.24
#
# new weight using weight_upward: 7.109999999999998
#
# ======================== Iteration: 12
# weight                 : 7.109999999999998
# prediction             : 142.19999999999996
# error                  : 1428.840000000003
# error (round)          : 1428.84
#
# weight_upward          : 7.119999999999997
# prediction_upward      : 142.39999999999995
# error_upward           : 1413.7600000000039
# error_upward (round)   : 1413.76
#
# weight_downwards       : 7.099999999999998
# prediction_downwards   : 141.99999999999994
# error_downwards        : 1444.0000000000043
# error_downwards (round): 1444.0
#
# new weight using weight_upward: 7.119999999999997
#
# ======================== Iteration: 13
# weight                 : 7.119999999999997
# prediction             : 142.39999999999995
# error                  : 1413.7600000000039
# error (round)          : 1413.76
#
# weight_upward          : 7.129999999999997
# prediction_upward      : 142.59999999999994
# error_upward           : 1398.7600000000048
# error_upward (round)   : 1398.76
#
# weight_downwards       : 7.109999999999998
# prediction_downwards   : 142.19999999999996
# error_downwards        : 1428.840000000003
# error_downwards (round): 1428.84
#
# new weight using weight_upward: 7.129999999999997
#
# ======================== Iteration: 14
# weight                 : 7.129999999999997
# prediction             : 142.59999999999994
# error                  : 1398.7600000000048
# error (round)          : 1398.76
#
# weight_upward          : 7.139999999999997
# prediction_upward      : 142.79999999999995
# error_upward           : 1383.8400000000033
# error_upward (round)   : 1383.84
#
# weight_downwards       : 7.119999999999997
# prediction_downwards   : 142.39999999999995
# error_downwards        : 1413.7600000000039
# error_downwards (round): 1413.76
#
# new weight using weight_upward: 7.139999999999997
#
# ======================== Iteration: 15
# weight                 : 7.139999999999997
# prediction             : 142.79999999999995
# error                  : 1383.8400000000033
# error (round)          : 1383.84
#
# weight_upward          : 7.149999999999997
# prediction_upward      : 142.99999999999994
# error_upward           : 1369.0000000000043
# error_upward (round)   : 1369.0
#
# weight_downwards       : 7.129999999999997
# prediction_downwards   : 142.59999999999994
# error_downwards        : 1398.7600000000048
# error_downwards (round): 1398.76
#
# new weight using weight_upward: 7.149999999999997
#
# ======================== Iteration: 16
# weight                 : 7.149999999999997
# prediction             : 142.99999999999994
# error                  : 1369.0000000000043
# error (round)          : 1369.0
#
# weight_upward          : 7.159999999999997
# prediction_upward      : 143.19999999999993
# error_upward           : 1354.240000000005
# error_upward (round)   : 1354.24
#
# weight_downwards       : 7.139999999999997
# prediction_downwards   : 142.79999999999995
# error_downwards        : 1383.8400000000033
# error_downwards (round): 1383.84
#
# new weight using weight_upward: 7.159999999999997
#
# ======================== Iteration: 17
# weight                 : 7.159999999999997
# prediction             : 143.19999999999993
# error                  : 1354.240000000005
# error (round)          : 1354.24
#
# weight_upward          : 7.169999999999996
# prediction_upward      : 143.39999999999992
# error_upward           : 1339.5600000000059
# error_upward (round)   : 1339.56
#
# weight_downwards       : 7.149999999999997
# prediction_downwards   : 142.99999999999994
# error_downwards        : 1369.0000000000043
# error_downwards (round): 1369.0
#
# new weight using weight_upward: 7.169999999999996
#
# ======================== Iteration: 18
# weight                 : 7.169999999999996
# prediction             : 143.39999999999992
# error                  : 1339.5600000000059
# error (round)          : 1339.56
#
# weight_upward          : 7.179999999999996
# prediction_upward      : 143.5999999999999
# error_upward           : 1324.9600000000066
# error_upward (round)   : 1324.96
#
# weight_downwards       : 7.159999999999997
# prediction_downwards   : 143.19999999999993
# error_downwards        : 1354.240000000005
# error_downwards (round): 1354.24
#
# new weight using weight_upward: 7.179999999999996
#
# ======================== Iteration: 19
# weight                 : 7.179999999999996
# prediction             : 143.5999999999999
# error                  : 1324.9600000000066
# error (round)          : 1324.96
#
# weight_upward          : 7.189999999999996
# prediction_upward      : 143.79999999999993
# error_upward           : 1310.4400000000053
# error_upward (round)   : 1310.44
#
# weight_downwards       : 7.169999999999996
# prediction_downwards   : 143.39999999999992
# error_downwards        : 1339.5600000000059
# error_downwards (round): 1339.56
#
# new weight using weight_upward: 7.189999999999996
#
# ======================== Iteration: 20
# weight                 : 7.189999999999996
# prediction             : 143.79999999999993
# error                  : 1310.4400000000053
# error (round)          : 1310.44
#
# weight_upward          : 7.199999999999996
# prediction_upward      : 143.99999999999991
# error_upward           : 1296.0000000000061
# error_upward (round)   : 1296.0
#
# weight_downwards       : 7.179999999999996
# prediction_downwards   : 143.5999999999999
# error_downwards        : 1324.9600000000066
# error_downwards (round): 1324.96
#
# new weight using weight_upward: 7.199999999999996
#
# ======================== Iteration: 21
# weight                 : 7.199999999999996
# prediction             : 143.99999999999991
# error                  : 1296.0000000000061
# error (round)          : 1296.0
#
# weight_upward          : 7.2099999999999955
# prediction_upward      : 144.1999999999999
# error_upward           : 1281.640000000007
# error_upward (round)   : 1281.64
#
# weight_downwards       : 7.189999999999996
# prediction_downwards   : 143.79999999999993
# error_downwards        : 1310.4400000000053
# error_downwards (round): 1310.44
#
# new weight using weight_upward: 7.2099999999999955
#
# ======================== Iteration: 22
# weight                 : 7.2099999999999955
# prediction             : 144.1999999999999
# error                  : 1281.640000000007
# error (round)          : 1281.64
#
# weight_upward          : 7.219999999999995
# prediction_upward      : 144.39999999999992
# error_upward           : 1267.3600000000056
# error_upward (round)   : 1267.36
#
# weight_downwards       : 7.199999999999996
# prediction_downwards   : 143.99999999999991
# error_downwards        : 1296.0000000000061
# error_downwards (round): 1296.0
#
# new weight using weight_upward: 7.219999999999995
#
# ======================== Iteration: 23
# weight                 : 7.219999999999995
# prediction             : 144.39999999999992
# error                  : 1267.3600000000056
# error (round)          : 1267.36
#
# weight_upward          : 7.229999999999995
# prediction_upward      : 144.5999999999999
# error_upward           : 1253.1600000000064
# error_upward (round)   : 1253.16
#
# weight_downwards       : 7.2099999999999955
# prediction_downwards   : 144.1999999999999
# error_downwards        : 1281.640000000007
# error_downwards (round): 1281.64
#
# new weight using weight_upward: 7.229999999999995
#
# ======================== Iteration: 24
# weight                 : 7.229999999999995
# prediction             : 144.5999999999999
# error                  : 1253.1600000000064
# error (round)          : 1253.16
#
# weight_upward          : 7.239999999999995
# prediction_upward      : 144.7999999999999
# error_upward           : 1239.0400000000072
# error_upward (round)   : 1239.04
#
# weight_downwards       : 7.219999999999995
# prediction_downwards   : 144.39999999999992
# error_downwards        : 1267.3600000000056
# error_downwards (round): 1267.36
#
# new weight using weight_upward: 7.239999999999995
#
# ======================== Iteration: 25
# weight                 : 7.239999999999995
# prediction             : 144.7999999999999
# error                  : 1239.0400000000072
# error (round)          : 1239.04
#
# weight_upward          : 7.249999999999995
# prediction_upward      : 144.9999999999999
# error_upward           : 1225.000000000008
# error_upward (round)   : 1225.0
#
# weight_downwards       : 7.229999999999995
# prediction_downwards   : 144.5999999999999
# error_downwards        : 1253.1600000000064
# error_downwards (round): 1253.16
#
# new weight using weight_upward: 7.249999999999995
#
# ======================== Iteration: 26
# weight                 : 7.249999999999995
# prediction             : 144.9999999999999
# error                  : 1225.000000000008
# error (round)          : 1225.0
#
# weight_upward          : 7.2599999999999945
# prediction_upward      : 145.19999999999987
# error_upward           : 1211.0400000000086
# error_upward (round)   : 1211.04
#
# weight_downwards       : 7.239999999999995
# prediction_downwards   : 144.7999999999999
# error_downwards        : 1239.0400000000072
# error_downwards (round): 1239.04
#
# new weight using weight_upward: 7.2599999999999945
#
# ======================== Iteration: 27
# weight                 : 7.2599999999999945
# prediction             : 145.19999999999987
# error                  : 1211.0400000000086
# error (round)          : 1211.04
#
# weight_upward          : 7.269999999999994
# prediction_upward      : 145.3999999999999
# error_upward           : 1197.1600000000076
# error_upward (round)   : 1197.16
#
# weight_downwards       : 7.249999999999995
# prediction_downwards   : 144.9999999999999
# error_downwards        : 1225.000000000008
# error_downwards (round): 1225.0
#
# new weight using weight_upward: 7.269999999999994
#
# ======================== Iteration: 28
# weight                 : 7.269999999999994
# prediction             : 145.3999999999999
# error                  : 1197.1600000000076
# error (round)          : 1197.16
#
# weight_upward          : 7.279999999999994
# prediction_upward      : 145.59999999999988
# error_upward           : 1183.3600000000083
# error_upward (round)   : 1183.36
#
# weight_downwards       : 7.2599999999999945
# prediction_downwards   : 145.19999999999987
# error_downwards        : 1211.0400000000086
# error_downwards (round): 1211.04
#
# new weight using weight_upward: 7.279999999999994
#
# ======================== Iteration: 29
# weight                 : 7.279999999999994
# prediction             : 145.59999999999988
# error                  : 1183.3600000000083
# error (round)          : 1183.36
#
# weight_upward          : 7.289999999999994
# prediction_upward      : 145.79999999999987
# error_upward           : 1169.640000000009
# error_upward (round)   : 1169.64
#
# weight_downwards       : 7.269999999999994
# prediction_downwards   : 145.3999999999999
# error_downwards        : 1197.1600000000076
# error_downwards (round): 1197.16
#
# new weight using weight_upward: 7.289999999999994
#
# ======================== Iteration: 30
# weight                 : 7.289999999999994
# prediction             : 145.79999999999987
# error                  : 1169.640000000009
# error (round)          : 1169.64
#
# weight_upward          : 7.299999999999994
# prediction_upward      : 145.9999999999999
# error_upward           : 1156.0000000000077
# error_upward (round)   : 1156.0
#
# weight_downwards       : 7.279999999999994
# prediction_downwards   : 145.59999999999988
# error_downwards        : 1183.3600000000083
# error_downwards (round): 1183.36
#
# new weight using weight_upward: 7.299999999999994
#
# ======================== Iteration: 31
# weight                 : 7.299999999999994
# prediction             : 145.9999999999999
# error                  : 1156.0000000000077
# error (round)          : 1156.0
#
# weight_upward          : 7.309999999999993
# prediction_upward      : 146.19999999999987
# error_upward           : 1142.4400000000085
# error_upward (round)   : 1142.44
#
# weight_downwards       : 7.289999999999994
# prediction_downwards   : 145.79999999999987
# error_downwards        : 1169.640000000009
# error_downwards (round): 1169.64
#
# new weight using weight_upward: 7.309999999999993
#
# ======================== Iteration: 32
# weight                 : 7.309999999999993
# prediction             : 146.19999999999987
# error                  : 1142.4400000000085
# error (round)          : 1142.44
#
# weight_upward          : 7.319999999999993
# prediction_upward      : 146.39999999999986
# error_upward           : 1128.9600000000091
# error_upward (round)   : 1128.96
#
# weight_downwards       : 7.299999999999994
# prediction_downwards   : 145.9999999999999
# error_downwards        : 1156.0000000000077
# error_downwards (round): 1156.0
#
# new weight using weight_upward: 7.319999999999993
#
# ======================== Iteration: 33
# weight                 : 7.319999999999993
# prediction             : 146.39999999999986
# error                  : 1128.9600000000091
# error (round)          : 1128.96
#
# weight_upward          : 7.329999999999993
# prediction_upward      : 146.59999999999985
# error_upward           : 1115.56000000001
# error_upward (round)   : 1115.56
#
# weight_downwards       : 7.309999999999993
# prediction_downwards   : 146.19999999999987
# error_downwards        : 1142.4400000000085
# error_downwards (round): 1142.44
#
# new weight using weight_upward: 7.329999999999993
#
# ======================== Iteration: 34
# weight                 : 7.329999999999993
# prediction             : 146.59999999999985
# error                  : 1115.56000000001
# error (round)          : 1115.56
#
# weight_upward          : 7.339999999999993
# prediction_upward      : 146.79999999999984
# error_upward           : 1102.2400000000105
# error_upward (round)   : 1102.24
#
# weight_downwards       : 7.319999999999993
# prediction_downwards   : 146.39999999999986
# error_downwards        : 1128.9600000000091
# error_downwards (round): 1128.96
#
# new weight using weight_upward: 7.339999999999993
#
# ======================== Iteration: 35
# weight                 : 7.339999999999993
# prediction             : 146.79999999999984
# error                  : 1102.2400000000105
# error (round)          : 1102.24
#
# weight_upward          : 7.3499999999999925
# prediction_upward      : 146.99999999999986
# error_upward           : 1089.0000000000093
# error_upward (round)   : 1089.0
#
# weight_downwards       : 7.329999999999993
# prediction_downwards   : 146.59999999999985
# error_downwards        : 1115.56000000001
# error_downwards (round): 1115.56
#
# new weight using weight_upward: 7.3499999999999925
#
# ======================== Iteration: 36
# weight                 : 7.3499999999999925
# prediction             : 146.99999999999986
# error                  : 1089.0000000000093
# error (round)          : 1089.0
#
# weight_upward          : 7.359999999999992
# prediction_upward      : 147.19999999999985
# error_upward           : 1075.8400000000101
# error_upward (round)   : 1075.84
#
# weight_downwards       : 7.339999999999993
# prediction_downwards   : 146.79999999999984
# error_downwards        : 1102.2400000000105
# error_downwards (round): 1102.24
#
# new weight using weight_upward: 7.359999999999992
#
# ======================== Iteration: 37
# weight                 : 7.359999999999992
# prediction             : 147.19999999999985
# error                  : 1075.8400000000101
# error (round)          : 1075.84
#
# weight_upward          : 7.369999999999992
# prediction_upward      : 147.39999999999984
# error_upward           : 1062.7600000000107
# error_upward (round)   : 1062.76
#
# weight_downwards       : 7.3499999999999925
# prediction_downwards   : 146.99999999999986
# error_downwards        : 1089.0000000000093
# error_downwards (round): 1089.0
#
# new weight using weight_upward: 7.369999999999992
#
# ======================== Iteration: 38
# weight                 : 7.369999999999992
# prediction             : 147.39999999999984
# error                  : 1062.7600000000107
# error (round)          : 1062.76
#
# weight_upward          : 7.379999999999992
# prediction_upward      : 147.59999999999985
# error_upward           : 1049.7600000000095
# error_upward (round)   : 1049.76
#
# weight_downwards       : 7.359999999999992
# prediction_downwards   : 147.19999999999985
# error_downwards        : 1075.8400000000101
# error_downwards (round): 1075.84
#
# new weight using weight_upward: 7.379999999999992
#
# ======================== Iteration: 39
# weight                 : 7.379999999999992
# prediction             : 147.59999999999985
# error                  : 1049.7600000000095
# error (round)          : 1049.76
#
# weight_upward          : 7.389999999999992
# prediction_upward      : 147.79999999999984
# error_upward           : 1036.8400000000101
# error_upward (round)   : 1036.84
#
# weight_downwards       : 7.369999999999992
# prediction_downwards   : 147.39999999999984
# error_downwards        : 1062.7600000000107
# error_downwards (round): 1062.76
#
# new weight using weight_upward: 7.389999999999992
#
# ======================== Iteration: 40
# weight                 : 7.389999999999992
# prediction             : 147.79999999999984
# error                  : 1036.8400000000101
# error (round)          : 1036.84
#
# weight_upward          : 7.3999999999999915
# prediction_upward      : 147.99999999999983
# error_upward           : 1024.000000000011
# error_upward (round)   : 1024.0
#
# weight_downwards       : 7.379999999999992
# prediction_downwards   : 147.59999999999985
# error_downwards        : 1049.7600000000095
# error_downwards (round): 1049.76
#
# new weight using weight_upward: 7.3999999999999915
#
# ======================== Iteration: 41
# weight                 : 7.3999999999999915
# prediction             : 147.99999999999983
# error                  : 1024.000000000011
# error (round)          : 1024.0
#
# weight_upward          : 7.409999999999991
# prediction_upward      : 148.19999999999982
# error_upward           : 1011.2400000000116
# error_upward (round)   : 1011.24
#
# weight_downwards       : 7.389999999999992
# prediction_downwards   : 147.79999999999984
# error_downwards        : 1036.8400000000101
# error_downwards (round): 1036.84
#
# new weight using weight_upward: 7.409999999999991
#
# ======================== Iteration: 42
# weight                 : 7.409999999999991
# prediction             : 148.19999999999982
# error                  : 1011.2400000000116
# error (round)          : 1011.24
#
# weight_upward          : 7.419999999999991
# prediction_upward      : 148.3999999999998
# error_upward           : 998.5600000000122
# error_upward (round)   : 998.56
#
# weight_downwards       : 7.3999999999999915
# prediction_downwards   : 147.99999999999983
# error_downwards        : 1024.000000000011
# error_downwards (round): 1024.0
#
# new weight using weight_upward: 7.419999999999991
#
# ======================== Iteration: 43
# weight                 : 7.419999999999991
# prediction             : 148.3999999999998
# error                  : 998.5600000000122
# error (round)          : 998.56
#
# weight_upward          : 7.429999999999991
# prediction_upward      : 148.59999999999982
# error_upward           : 985.9600000000111
# error_upward (round)   : 985.96
#
# weight_downwards       : 7.409999999999991
# prediction_downwards   : 148.19999999999982
# error_downwards        : 1011.2400000000116
# error_downwards (round): 1011.24
#
# new weight using weight_upward: 7.429999999999991
#
# ======================== Iteration: 44
# weight                 : 7.429999999999991
# prediction             : 148.59999999999982
# error                  : 985.9600000000111
# error (round)          : 985.96
#
# weight_upward          : 7.439999999999991
# prediction_upward      : 148.7999999999998
# error_upward           : 973.4400000000117
# error_upward (round)   : 973.44
#
# weight_downwards       : 7.419999999999991
# prediction_downwards   : 148.3999999999998
# error_downwards        : 998.5600000000122
# error_downwards (round): 998.56
#
# new weight using weight_upward: 7.439999999999991
#
# ======================== Iteration: 45
# weight                 : 7.439999999999991
# prediction             : 148.7999999999998
# error                  : 973.4400000000117
# error (round)          : 973.44
#
# weight_upward          : 7.44999999999999
# prediction_upward      : 148.9999999999998
# error_upward           : 961.0000000000123
# error_upward (round)   : 961.0
#
# weight_downwards       : 7.429999999999991
# prediction_downwards   : 148.59999999999982
# error_downwards        : 985.9600000000111
# error_downwards (round): 985.96
#
# new weight using weight_upward: 7.44999999999999
#
# ======================== Iteration: 46
# weight                 : 7.44999999999999
# prediction             : 148.9999999999998
# error                  : 961.0000000000123
# error (round)          : 961.0
#
# weight_upward          : 7.45999999999999
# prediction_upward      : 149.19999999999982
# error_upward           : 948.6400000000112
# error_upward (round)   : 948.64
#
# weight_downwards       : 7.439999999999991
# prediction_downwards   : 148.7999999999998
# error_downwards        : 973.4400000000117
# error_downwards (round): 973.44
#
# new weight using weight_upward: 7.45999999999999
#
# ======================== Iteration: 47
# weight                 : 7.45999999999999
# prediction             : 149.19999999999982
# error                  : 948.6400000000112
# error (round)          : 948.64
#
# weight_upward          : 7.46999999999999
# prediction_upward      : 149.3999999999998
# error_upward           : 936.3600000000118
# error_upward (round)   : 936.36
#
# weight_downwards       : 7.44999999999999
# prediction_downwards   : 148.9999999999998
# error_downwards        : 961.0000000000123
# error_downwards (round): 961.0
#
# new weight using weight_upward: 7.46999999999999
#
# ======================== Iteration: 48
# weight                 : 7.46999999999999
# prediction             : 149.3999999999998
# error                  : 936.3600000000118
# error (round)          : 936.36
#
# weight_upward          : 7.47999999999999
# prediction_upward      : 149.5999999999998
# error_upward           : 924.1600000000125
# error_upward (round)   : 924.16
#
# weight_downwards       : 7.45999999999999
# prediction_downwards   : 149.19999999999982
# error_downwards        : 948.6400000000112
# error_downwards (round): 948.64
#
# new weight using weight_upward: 7.47999999999999
#
# ======================== Iteration: 49
# weight                 : 7.47999999999999
# prediction             : 149.5999999999998
# error                  : 924.1600000000125
# error (round)          : 924.16
#
# weight_upward          : 7.4899999999999896
# prediction_upward      : 149.79999999999978
# error_upward           : 912.040000000013
# error_upward (round)   : 912.04
#
# weight_downwards       : 7.46999999999999
# prediction_downwards   : 149.3999999999998
# error_downwards        : 936.3600000000118
# error_downwards (round): 936.36
#
# new weight using weight_upward: 7.4899999999999896
#
# ======================== Iteration: 50
# weight                 : 7.4899999999999896
# prediction             : 149.79999999999978
# error                  : 912.040000000013
# error (round)          : 912.04
#
# weight_upward          : 7.499999999999989
# prediction_upward      : 149.99999999999977
# error_upward           : 900.0000000000136
# error_upward (round)   : 900.0
#
# weight_downwards       : 7.47999999999999
# prediction_downwards   : 149.5999999999998
# error_downwards        : 924.1600000000125
# error_downwards (round): 924.16
#
# new weight using weight_upward: 7.499999999999989
#
# ======================== Iteration: 51
# weight                 : 7.499999999999989
# prediction             : 149.99999999999977
# error                  : 900.0000000000136
# error (round)          : 900.0
#
# weight_upward          : 7.509999999999989
# prediction_upward      : 150.1999999999998
# error_upward           : 888.0400000000126
# error_upward (round)   : 888.04
#
# weight_downwards       : 7.4899999999999896
# prediction_downwards   : 149.79999999999978
# error_downwards        : 912.040000000013
# error_downwards (round): 912.04
#
# new weight using weight_upward: 7.509999999999989
#
# ======================== Iteration: 52
# weight                 : 7.509999999999989
# prediction             : 150.1999999999998
# error                  : 888.0400000000126
# error (round)          : 888.04
#
# weight_upward          : 7.519999999999989
# prediction_upward      : 150.39999999999978
# error_upward           : 876.1600000000132
# error_upward (round)   : 876.16
#
# weight_downwards       : 7.499999999999989
# prediction_downwards   : 149.99999999999977
# error_downwards        : 900.0000000000136
# error_downwards (round): 900.0
#
# new weight using weight_upward: 7.519999999999989
#
# ======================== Iteration: 53
# weight                 : 7.519999999999989
# prediction             : 150.39999999999978
# error                  : 876.1600000000132
# error (round)          : 876.16
#
# weight_upward          : 7.529999999999989
# prediction_upward      : 150.59999999999977
# error_upward           : 864.3600000000137
# error_upward (round)   : 864.36
#
# weight_downwards       : 7.509999999999989
# prediction_downwards   : 150.1999999999998
# error_downwards        : 888.0400000000126
# error_downwards (round): 888.04
#
# new weight using weight_upward: 7.529999999999989
#
# ======================== Iteration: 54
# weight                 : 7.529999999999989
# prediction             : 150.59999999999977
# error                  : 864.3600000000137
# error (round)          : 864.36
#
# weight_upward          : 7.5399999999999885
# prediction_upward      : 150.79999999999978
# error_upward           : 852.6400000000126
# error_upward (round)   : 852.64
#
# weight_downwards       : 7.519999999999989
# prediction_downwards   : 150.39999999999978
# error_downwards        : 876.1600000000132
# error_downwards (round): 876.16
#
# new weight using weight_upward: 7.5399999999999885
#
# ======================== Iteration: 55
# weight                 : 7.5399999999999885
# prediction             : 150.79999999999978
# error                  : 852.6400000000126
# error (round)          : 852.64
#
# weight_upward          : 7.549999999999988
# prediction_upward      : 150.99999999999977
# error_upward           : 841.0000000000132
# error_upward (round)   : 841.0
#
# weight_downwards       : 7.529999999999989
# prediction_downwards   : 150.59999999999977
# error_downwards        : 864.3600000000137
# error_downwards (round): 864.36
#
# new weight using weight_upward: 7.549999999999988
#
# ======================== Iteration: 56
# weight                 : 7.549999999999988
# prediction             : 150.99999999999977
# error                  : 841.0000000000132
# error (round)          : 841.0
#
# weight_upward          : 7.559999999999988
# prediction_upward      : 151.19999999999976
# error_upward           : 829.4400000000137
# error_upward (round)   : 829.44
#
# weight_downwards       : 7.5399999999999885
# prediction_downwards   : 150.79999999999978
# error_downwards        : 852.6400000000126
# error_downwards (round): 852.64
#
# new weight using weight_upward: 7.559999999999988
#
# ======================== Iteration: 57
# weight                 : 7.559999999999988
# prediction             : 151.19999999999976
# error                  : 829.4400000000137
# error (round)          : 829.44
#
# weight_upward          : 7.569999999999988
# prediction_upward      : 151.39999999999975
# error_upward           : 817.9600000000144
# error_upward (round)   : 817.96
#
# weight_downwards       : 7.549999999999988
# prediction_downwards   : 150.99999999999977
# error_downwards        : 841.0000000000132
# error_downwards (round): 841.0
#
# new weight using weight_upward: 7.569999999999988
#
# ======================== Iteration: 58
# weight                 : 7.569999999999988
# prediction             : 151.39999999999975
# error                  : 817.9600000000144
# error (round)          : 817.96
#
# weight_upward          : 7.579999999999988
# prediction_upward      : 151.59999999999974
# error_upward           : 806.5600000000148
# error_upward (round)   : 806.56
#
# weight_downwards       : 7.559999999999988
# prediction_downwards   : 151.19999999999976
# error_downwards        : 829.4400000000137
# error_downwards (round): 829.44
#
# new weight using weight_upward: 7.579999999999988
#
# ======================== Iteration: 59
# weight                 : 7.579999999999988
# prediction             : 151.59999999999974
# error                  : 806.5600000000148
# error (round)          : 806.56
#
# weight_upward          : 7.589999999999987
# prediction_upward      : 151.79999999999976
# error_upward           : 795.2400000000138
# error_upward (round)   : 795.24
#
# weight_downwards       : 7.569999999999988
# prediction_downwards   : 151.39999999999975
# error_downwards        : 817.9600000000144
# error_downwards (round): 817.96
#
# new weight using weight_upward: 7.589999999999987
#
# ======================== Iteration: 60
# weight                 : 7.589999999999987
# prediction             : 151.79999999999976
# error                  : 795.2400000000138
# error (round)          : 795.24
#
# weight_upward          : 7.599999999999987
# prediction_upward      : 151.99999999999974
# error_upward           : 784.0000000000143
# error_upward (round)   : 784.0
#
# weight_downwards       : 7.579999999999988
# prediction_downwards   : 151.59999999999974
# error_downwards        : 806.5600000000148
# error_downwards (round): 806.56
#
# new weight using weight_upward: 7.599999999999987
#
# ======================== Iteration: 61
# weight                 : 7.599999999999987
# prediction             : 151.99999999999974
# error                  : 784.0000000000143
# error (round)          : 784.0
#
# weight_upward          : 7.609999999999987
# prediction_upward      : 152.19999999999973
# error_upward           : 772.8400000000148
# error_upward (round)   : 772.84
#
# weight_downwards       : 7.589999999999987
# prediction_downwards   : 151.79999999999976
# error_downwards        : 795.2400000000138
# error_downwards (round): 795.24
#
# new weight using weight_upward: 7.609999999999987
#
# ======================== Iteration: 62
# weight                 : 7.609999999999987
# prediction             : 152.19999999999973
# error                  : 772.8400000000148
# error (round)          : 772.84
#
# weight_upward          : 7.619999999999987
# prediction_upward      : 152.39999999999975
# error_upward           : 761.7600000000139
# error_upward (round)   : 761.76
#
# weight_downwards       : 7.599999999999987
# prediction_downwards   : 151.99999999999974
# error_downwards        : 784.0000000000143
# error_downwards (round): 784.0
#
# new weight using weight_upward: 7.619999999999987
#
# ======================== Iteration: 63
# weight                 : 7.619999999999987
# prediction             : 152.39999999999975
# error                  : 761.7600000000139
# error (round)          : 761.76
#
# weight_upward          : 7.629999999999987
# prediction_upward      : 152.59999999999974
# error_upward           : 750.7600000000143
# error_upward (round)   : 750.76
#
# weight_downwards       : 7.609999999999987
# prediction_downwards   : 152.19999999999973
# error_downwards        : 772.8400000000148
# error_downwards (round): 772.84
#
# new weight using weight_upward: 7.629999999999987
#
# ======================== Iteration: 64
# weight                 : 7.629999999999987
# prediction             : 152.59999999999974
# error                  : 750.7600000000143
# error (round)          : 750.76
#
# weight_upward          : 7.639999999999986
# prediction_upward      : 152.79999999999973
# error_upward           : 739.8400000000148
# error_upward (round)   : 739.84
#
# weight_downwards       : 7.619999999999987
# prediction_downwards   : 152.39999999999975
# error_downwards        : 761.7600000000139
# error_downwards (round): 761.76
#
# new weight using weight_upward: 7.639999999999986
#
# ======================== Iteration: 65
# weight                 : 7.639999999999986
# prediction             : 152.79999999999973
# error                  : 739.8400000000148
# error (round)          : 739.84
#
# weight_upward          : 7.649999999999986
# prediction_upward      : 152.99999999999972
# error_upward           : 729.0000000000153
# error_upward (round)   : 729.0
#
# weight_downwards       : 7.629999999999987
# prediction_downwards   : 152.59999999999974
# error_downwards        : 750.7600000000143
# error_downwards (round): 750.76
#
# new weight using weight_upward: 7.649999999999986
#
# ======================== Iteration: 66
# weight                 : 7.649999999999986
# prediction             : 152.99999999999972
# error                  : 729.0000000000153
# error (round)          : 729.0
#
# weight_upward          : 7.659999999999986
# prediction_upward      : 153.1999999999997
# error_upward           : 718.2400000000158
# error_upward (round)   : 718.24
#
# weight_downwards       : 7.639999999999986
# prediction_downwards   : 152.79999999999973
# error_downwards        : 739.8400000000148
# error_downwards (round): 739.84
#
# new weight using weight_upward: 7.659999999999986
#
# ======================== Iteration: 67
# weight                 : 7.659999999999986
# prediction             : 153.1999999999997
# error                  : 718.2400000000158
# error (round)          : 718.24
#
# weight_upward          : 7.669999999999986
# prediction_upward      : 153.39999999999972
# error_upward           : 707.5600000000148
# error_upward (round)   : 707.56
#
# weight_downwards       : 7.649999999999986
# prediction_downwards   : 152.99999999999972
# error_downwards        : 729.0000000000153
# error_downwards (round): 729.0
#
# new weight using weight_upward: 7.669999999999986
#
# ======================== Iteration: 68
# weight                 : 7.669999999999986
# prediction             : 153.39999999999972
# error                  : 707.5600000000148
# error (round)          : 707.56
#
# weight_upward          : 7.6799999999999855
# prediction_upward      : 153.5999999999997
# error_upward           : 696.9600000000153
# error_upward (round)   : 696.96
#
# weight_downwards       : 7.659999999999986
# prediction_downwards   : 153.1999999999997
# error_downwards        : 718.2400000000158
# error_downwards (round): 718.24
#
# new weight using weight_upward: 7.6799999999999855
#
# ======================== Iteration: 69
# weight                 : 7.6799999999999855
# prediction             : 153.5999999999997
# error                  : 696.9600000000153
# error (round)          : 696.96
#
# weight_upward          : 7.689999999999985
# prediction_upward      : 153.7999999999997
# error_upward           : 686.4400000000157
# error_upward (round)   : 686.44
#
# weight_downwards       : 7.669999999999986
# prediction_downwards   : 153.39999999999972
# error_downwards        : 707.5600000000148
# error_downwards (round): 707.56
#
# new weight using weight_upward: 7.689999999999985
#
# ======================== Iteration: 70
# weight                 : 7.689999999999985
# prediction             : 153.7999999999997
# error                  : 686.4400000000157
# error (round)          : 686.44
#
# weight_upward          : 7.699999999999985
# prediction_upward      : 153.99999999999972
# error_upward           : 676.0000000000148
# error_upward (round)   : 676.0
#
# weight_downwards       : 7.6799999999999855
# prediction_downwards   : 153.5999999999997
# error_downwards        : 696.9600000000153
# error_downwards (round): 696.96
#
# new weight using weight_upward: 7.699999999999985
#
# ======================== Iteration: 71
# weight                 : 7.699999999999985
# prediction             : 153.99999999999972
# error                  : 676.0000000000148
# error (round)          : 676.0
#
# weight_upward          : 7.709999999999985
# prediction_upward      : 154.1999999999997
# error_upward           : 665.6400000000152
# error_upward (round)   : 665.64
#
# weight_downwards       : 7.689999999999985
# prediction_downwards   : 153.7999999999997
# error_downwards        : 686.4400000000157
# error_downwards (round): 686.44
#
# new weight using weight_upward: 7.709999999999985
#
# ======================== Iteration: 72
# weight                 : 7.709999999999985
# prediction             : 154.1999999999997
# error                  : 665.6400000000152
# error (round)          : 665.64
#
# weight_upward          : 7.719999999999985
# prediction_upward      : 154.3999999999997
# error_upward           : 655.3600000000157
# error_upward (round)   : 655.36
#
# weight_downwards       : 7.699999999999985
# prediction_downwards   : 153.99999999999972
# error_downwards        : 676.0000000000148
# error_downwards (round): 676.0
#
# new weight using weight_upward: 7.719999999999985
#
# ======================== Iteration: 73
# weight                 : 7.719999999999985
# prediction             : 154.3999999999997
# error                  : 655.3600000000157
# error (round)          : 655.36
#
# weight_upward          : 7.729999999999984
# prediction_upward      : 154.59999999999968
# error_upward           : 645.1600000000162
# error_upward (round)   : 645.16
#
# weight_downwards       : 7.709999999999985
# prediction_downwards   : 154.1999999999997
# error_downwards        : 665.6400000000152
# error_downwards (round): 665.64
#
# new weight using weight_upward: 7.729999999999984
#
# ======================== Iteration: 74
# weight                 : 7.729999999999984
# prediction             : 154.59999999999968
# error                  : 645.1600000000162
# error (round)          : 645.16
#
# weight_upward          : 7.739999999999984
# prediction_upward      : 154.79999999999967
# error_upward           : 635.0400000000166
# error_upward (round)   : 635.04
#
# weight_downwards       : 7.719999999999985
# prediction_downwards   : 154.3999999999997
# error_downwards        : 655.3600000000157
# error_downwards (round): 655.36
#
# new weight using weight_upward: 7.739999999999984
#
# ======================== Iteration: 75
# weight                 : 7.739999999999984
# prediction             : 154.79999999999967
# error                  : 635.0400000000166
# error (round)          : 635.04
#
# weight_upward          : 7.749999999999984
# prediction_upward      : 154.9999999999997
# error_upward           : 625.0000000000157
# error_upward (round)   : 625.0
#
# weight_downwards       : 7.729999999999984
# prediction_downwards   : 154.59999999999968
# error_downwards        : 645.1600000000162
# error_downwards (round): 645.16
#
# new weight using weight_upward: 7.749999999999984
#
# ======================== Iteration: 76
# weight                 : 7.749999999999984
# prediction             : 154.9999999999997
# error                  : 625.0000000000157
# error (round)          : 625.0
#
# weight_upward          : 7.759999999999984
# prediction_upward      : 155.19999999999968
# error_upward           : 615.0400000000161
# error_upward (round)   : 615.04
#
# weight_downwards       : 7.739999999999984
# prediction_downwards   : 154.79999999999967
# error_downwards        : 635.0400000000166
# error_downwards (round): 635.04
#
# new weight using weight_upward: 7.759999999999984
#
# ======================== Iteration: 77
# weight                 : 7.759999999999984
# prediction             : 155.19999999999968
# error                  : 615.0400000000161
# error (round)          : 615.04
#
# weight_upward          : 7.769999999999984
# prediction_upward      : 155.39999999999966
# error_upward           : 605.1600000000165
# error_upward (round)   : 605.16
#
# weight_downwards       : 7.749999999999984
# prediction_downwards   : 154.9999999999997
# error_downwards        : 625.0000000000157
# error_downwards (round): 625.0
#
# new weight using weight_upward: 7.769999999999984
#
# ======================== Iteration: 78
# weight                 : 7.769999999999984
# prediction             : 155.39999999999966
# error                  : 605.1600000000165
# error (round)          : 605.16
#
# weight_upward          : 7.779999999999983
# prediction_upward      : 155.59999999999968
# error_upward           : 595.3600000000156
# error_upward (round)   : 595.36
#
# weight_downwards       : 7.759999999999984
# prediction_downwards   : 155.19999999999968
# error_downwards        : 615.0400000000161
# error_downwards (round): 615.04
#
# new weight using weight_upward: 7.779999999999983
#
# ======================== Iteration: 79
# weight                 : 7.779999999999983
# prediction             : 155.59999999999968
# error                  : 595.3600000000156
# error (round)          : 595.36
#
# weight_upward          : 7.789999999999983
# prediction_upward      : 155.79999999999967
# error_upward           : 585.6400000000159
# error_upward (round)   : 585.64
#
# weight_downwards       : 7.769999999999984
# prediction_downwards   : 155.39999999999966
# error_downwards        : 605.1600000000165
# error_downwards (round): 605.16
#
# new weight using weight_upward: 7.789999999999983
#
# ======================== Iteration: 80
# weight                 : 7.789999999999983
# prediction             : 155.79999999999967
# error                  : 585.6400000000159
# error (round)          : 585.64
#
# weight_upward          : 7.799999999999983
# prediction_upward      : 155.99999999999966
# error_upward           : 576.0000000000164
# error_upward (round)   : 576.0
#
# weight_downwards       : 7.779999999999983
# prediction_downwards   : 155.59999999999968
# error_downwards        : 595.3600000000156
# error_downwards (round): 595.36
#
# new weight using weight_upward: 7.799999999999983
#
# ======================== Iteration: 81
# weight                 : 7.799999999999983
# prediction             : 155.99999999999966
# error                  : 576.0000000000164
# error (round)          : 576.0
#
# weight_upward          : 7.809999999999983
# prediction_upward      : 156.19999999999965
# error_upward           : 566.4400000000168
# error_upward (round)   : 566.44
#
# weight_downwards       : 7.789999999999983
# prediction_downwards   : 155.79999999999967
# error_downwards        : 585.6400000000159
# error_downwards (round): 585.64
#
# new weight using weight_upward: 7.809999999999983
#
# ======================== Iteration: 82
# weight                 : 7.809999999999983
# prediction             : 156.19999999999965
# error                  : 566.4400000000168
# error (round)          : 566.44
#
# weight_upward          : 7.8199999999999825
# prediction_upward      : 156.39999999999964
# error_upward           : 556.9600000000172
# error_upward (round)   : 556.96
#
# weight_downwards       : 7.799999999999983
# prediction_downwards   : 155.99999999999966
# error_downwards        : 576.0000000000164
# error_downwards (round): 576.0
#
# new weight using weight_upward: 7.8199999999999825
#
# ======================== Iteration: 83
# weight                 : 7.8199999999999825
# prediction             : 156.39999999999964
# error                  : 556.9600000000172
# error (round)          : 556.96
#
# weight_upward          : 7.829999999999982
# prediction_upward      : 156.59999999999965
# error_upward           : 547.5600000000162
# error_upward (round)   : 547.56
#
# weight_downwards       : 7.809999999999983
# prediction_downwards   : 156.19999999999965
# error_downwards        : 566.4400000000168
# error_downwards (round): 566.44
#
# new weight using weight_upward: 7.829999999999982
#
# ======================== Iteration: 84
# weight                 : 7.829999999999982
# prediction             : 156.59999999999965
# error                  : 547.5600000000162
# error (round)          : 547.56
#
# weight_upward          : 7.839999999999982
# prediction_upward      : 156.79999999999964
# error_upward           : 538.2400000000166
# error_upward (round)   : 538.24
#
# weight_downwards       : 7.8199999999999825
# prediction_downwards   : 156.39999999999964
# error_downwards        : 556.9600000000172
# error_downwards (round): 556.96
#
# new weight using weight_upward: 7.839999999999982
#
# ======================== Iteration: 85
# weight                 : 7.839999999999982
# prediction             : 156.79999999999964
# error                  : 538.2400000000166
# error (round)          : 538.24
#
# weight_upward          : 7.849999999999982
# prediction_upward      : 156.99999999999963
# error_upward           : 529.000000000017
# error_upward (round)   : 529.0
#
# weight_downwards       : 7.829999999999982
# prediction_downwards   : 156.59999999999965
# error_downwards        : 547.5600000000162
# error_downwards (round): 547.56
#
# new weight using weight_upward: 7.849999999999982
#
# ======================== Iteration: 86
# weight                 : 7.849999999999982
# prediction             : 156.99999999999963
# error                  : 529.000000000017
# error (round)          : 529.0
#
# weight_upward          : 7.859999999999982
# prediction_upward      : 157.19999999999965
# error_upward           : 519.8400000000161
# error_upward (round)   : 519.84
#
# weight_downwards       : 7.839999999999982
# prediction_downwards   : 156.79999999999964
# error_downwards        : 538.2400000000166
# error_downwards (round): 538.24
#
# new weight using weight_upward: 7.859999999999982
#
# ======================== Iteration: 87
# weight                 : 7.859999999999982
# prediction             : 157.19999999999965
# error                  : 519.8400000000161
# error (round)          : 519.84
#
# weight_upward          : 7.8699999999999815
# prediction_upward      : 157.39999999999964
# error_upward           : 510.7600000000164
# error_upward (round)   : 510.76
#
# weight_downwards       : 7.849999999999982
# prediction_downwards   : 156.99999999999963
# error_downwards        : 529.000000000017
# error_downwards (round): 529.0
#
# new weight using weight_upward: 7.8699999999999815
#
# ======================== Iteration: 88
# weight                 : 7.8699999999999815
# prediction             : 157.39999999999964
# error                  : 510.7600000000164
# error (round)          : 510.76
#
# weight_upward          : 7.879999999999981
# prediction_upward      : 157.59999999999962
# error_upward           : 501.7600000000168
# error_upward (round)   : 501.76
#
# weight_downwards       : 7.859999999999982
# prediction_downwards   : 157.19999999999965
# error_downwards        : 519.8400000000161
# error_downwards (round): 519.84
#
# new weight using weight_upward: 7.879999999999981
#
# ======================== Iteration: 89
# weight                 : 7.879999999999981
# prediction             : 157.59999999999962
# error                  : 501.7600000000168
# error (round)          : 501.76
#
# weight_upward          : 7.889999999999981
# prediction_upward      : 157.7999999999996
# error_upward           : 492.84000000001714
# error_upward (round)   : 492.84
#
# weight_downwards       : 7.8699999999999815
# prediction_downwards   : 157.39999999999964
# error_downwards        : 510.7600000000164
# error_downwards (round): 510.76
#
# new weight using weight_upward: 7.889999999999981
#
# ======================== Iteration: 90
# weight                 : 7.889999999999981
# prediction             : 157.7999999999996
# error                  : 492.84000000001714
# error (round)          : 492.84
#
# weight_upward          : 7.899999999999981
# prediction_upward      : 157.9999999999996
# error_upward           : 484.0000000000175
# error_upward (round)   : 484.0
#
# weight_downwards       : 7.879999999999981
# prediction_downwards   : 157.59999999999962
# error_downwards        : 501.7600000000168
# error_downwards (round): 501.76
#
# new weight using weight_upward: 7.899999999999981
#
# ======================== Iteration: 91
# weight                 : 7.899999999999981
# prediction             : 157.9999999999996
# error                  : 484.0000000000175
# error (round)          : 484.0
#
# weight_upward          : 7.909999999999981
# prediction_upward      : 158.19999999999962
# error_upward           : 475.2400000000166
# error_upward (round)   : 475.24
#
# weight_downwards       : 7.889999999999981
# prediction_downwards   : 157.7999999999996
# error_downwards        : 492.84000000001714
# error_downwards (round): 492.84
#
# new weight using weight_upward: 7.909999999999981
#
# ======================== Iteration: 92
# weight                 : 7.909999999999981
# prediction             : 158.19999999999962
# error                  : 475.2400000000166
# error (round)          : 475.24
#
# weight_upward          : 7.91999999999998
# prediction_upward      : 158.3999999999996
# error_upward           : 466.56000000001694
# error_upward (round)   : 466.56
#
# weight_downwards       : 7.899999999999981
# prediction_downwards   : 157.9999999999996
# error_downwards        : 484.0000000000175
# error_downwards (round): 484.0
#
# new weight using weight_upward: 7.91999999999998
#
# ======================== Iteration: 93
# weight                 : 7.91999999999998
# prediction             : 158.3999999999996
# error                  : 466.56000000001694
# error (round)          : 466.56
#
# weight_upward          : 7.92999999999998
# prediction_upward      : 158.5999999999996
# error_upward           : 457.96000000001726
# error_upward (round)   : 457.96
#
# weight_downwards       : 7.909999999999981
# prediction_downwards   : 158.19999999999962
# error_downwards        : 475.2400000000166
# error_downwards (round): 475.24
#
# new weight using weight_upward: 7.92999999999998
#
# ======================== Iteration: 94
# weight                 : 7.92999999999998
# prediction             : 158.5999999999996
# error                  : 457.96000000001726
# error (round)          : 457.96
#
# weight_upward          : 7.93999999999998
# prediction_upward      : 158.7999999999996
# error_upward           : 449.44000000001637
# error_upward (round)   : 449.44
#
# weight_downwards       : 7.91999999999998
# prediction_downwards   : 158.3999999999996
# error_downwards        : 466.56000000001694
# error_downwards (round): 466.56
#
# new weight using weight_upward: 7.93999999999998
#
# ======================== Iteration: 95
# weight                 : 7.93999999999998
# prediction             : 158.7999999999996
# error                  : 449.44000000001637
# error (round)          : 449.44
#
# weight_upward          : 7.94999999999998
# prediction_upward      : 158.9999999999996
# error_upward           : 441.0000000000167
# error_upward (round)   : 441.0
#
# weight_downwards       : 7.92999999999998
# prediction_downwards   : 158.5999999999996
# error_downwards        : 457.96000000001726
# error_downwards (round): 457.96
#
# new weight using weight_upward: 7.94999999999998
#
# ======================== Iteration: 96
# weight                 : 7.94999999999998
# prediction             : 158.9999999999996
# error                  : 441.0000000000167
# error (round)          : 441.0
#
# weight_upward          : 7.9599999999999795
# prediction_upward      : 159.1999999999996
# error_upward           : 432.64000000001704
# error_upward (round)   : 432.64
#
# weight_downwards       : 7.93999999999998
# prediction_downwards   : 158.7999999999996
# error_downwards        : 449.44000000001637
# error_downwards (round): 449.44
#
# new weight using weight_upward: 7.9599999999999795
#
# ======================== Iteration: 97
# weight                 : 7.9599999999999795
# prediction             : 159.1999999999996
# error                  : 432.64000000001704
# error (round)          : 432.64
#
# weight_upward          : 7.969999999999979
# prediction_upward      : 159.39999999999958
# error_upward           : 424.36000000001735
# error_upward (round)   : 424.36
#
# weight_downwards       : 7.94999999999998
# prediction_downwards   : 158.9999999999996
# error_downwards        : 441.0000000000167
# error_downwards (round): 441.0
#
# new weight using weight_upward: 7.969999999999979
#
# ======================== Iteration: 98
# weight                 : 7.969999999999979
# prediction             : 159.39999999999958
# error                  : 424.36000000001735
# error (round)          : 424.36
#
# weight_upward          : 7.979999999999979
# prediction_upward      : 159.59999999999957
# error_upward           : 416.16000000001765
# error_upward (round)   : 416.16
#
# weight_downwards       : 7.9599999999999795
# prediction_downwards   : 159.1999999999996
# error_downwards        : 432.64000000001704
# error_downwards (round): 432.64
#
# new weight using weight_upward: 7.979999999999979
#
# ======================== Iteration: 99
# weight                 : 7.979999999999979
# prediction             : 159.59999999999957
# error                  : 416.16000000001765
# error (round)          : 416.16
#
# weight_upward          : 7.989999999999979
# prediction_upward      : 159.79999999999959
# error_upward           : 408.0400000000168
# error_upward (round)   : 408.04
#
# weight_downwards       : 7.969999999999979
# prediction_downwards   : 159.39999999999958
# error_downwards        : 424.36000000001735
# error_downwards (round): 424.36
#
# new weight using weight_upward: 7.989999999999979
#
# ======================== Iteration: 100
# weight                 : 7.989999999999979
# prediction             : 159.79999999999959
# error                  : 408.0400000000168
# error (round)          : 408.04
#
# weight_upward          : 7.999999999999979
# prediction_upward      : 159.99999999999957
# error_upward           : 400.00000000001705
# error_upward (round)   : 400.0
#
# weight_downwards       : 7.979999999999979
# prediction_downwards   : 159.59999999999957
# error_downwards        : 416.16000000001765
# error_downwards (round): 416.16
