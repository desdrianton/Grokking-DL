# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in z:\10__python\3.12.4\lib\site-packages (2.0.1)
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

#########################################################################
# NN function
#########################################################################
def do_learning(inputs, initial_weights, expected_values, alpha):

    print("########################################")
    print(f"- Input             : \n{inputs}\n")
    print(f"- initial_weights   : \n{initial_weights}\n")
    print(f"- expected_value    : \n{expected_values}\n")
    print(f"- alpha             : \n{alpha}\n")
    print("########################################")
    
    need_learning = True
    weights = initial_weights
    iteration = 1

    inputs_size = inputs.size
    expected_values_size = expected_values.size

    weights = weights.reshape(inputs_size, expected_values_size)
    expected_values = expected_values.reshape(1, expected_values_size)

    while need_learning:
        print(f"==================== Iteration {iteration}")
        print("----- Setup -----")
        print(f"- Input             : \n{inputs}\n")
        print(f"- expected_value    : \n{expected_values}\n")
        print(f"- alpha             : \n{alpha}\n")
        print()

        # 2. NN Prediction
        print("----- NN Prediction -----")
        print(f"- weight            : \n{weights}\n")

        predicted_values = inputs.dot(weights)
        
        print(f"- predicted_value   : \n{predicted_values}\n")
        print()

        # 3. Calculate Error
        deltas = predicted_values - expected_values
        errors = deltas ** 2
        print("----- Calculate Error -----")
        print(f"- delta             : \n{deltas}\n")
        print(f"- error             : \n{errors}\n")
        print()

        # 4. Weight Adjustment
        error_derivatives = 2 * inputs * deltas
        # error_derivatives = error_derivatives.reshape(inputs_size, expected_values_size)
        error_derivatives = error_derivatives.reshape(inputs_size, 1)
        weight_adjustments = alpha * error_derivatives
        new_weights = weights - weight_adjustments
        print("----- Weight Adjustment -----")
        print(f"- error_derivative  : \n{error_derivatives}\n")
        print(f"- weight_adjustment : \n{weight_adjustments}\n")
        print(f"- new_weight        : \n{new_weights}\n")
        print()

        # 5. Still need learning?
        total_error = round(np.sum(errors), 5)
        need_learning = (total_error != 0)
        print("----- Need Learning -----")
        print(f"- total_error     : \n{total_error}\n")
        print(f"- need_learning     : \n{need_learning}\n")
        print()

        # Print information    

        # Update weight for next iteration
        weights = new_weights

        # Circuit breaker (max 1000 iteration)
        iteration = iteration + 1
        if(iteration > 1000):
            break


#########################################################################
# Run
#########################################################################

# Case 1: SISO
# This case will do 11 iterations until has zero error
# inputs = np.array([0.2])
# initial_weights = np.array([10])
# expected_values = np.array([8])
# alpha = 18

# Case 2: MISO
# This case will do 23 iterations until has zero error
# inputs = np.array([0.2, 4, 0.1])
# initial_weights = np.array([0, 0, 0])
# expected_values = np.array([8])
# alpha = 0.01

# Case 3: SIMO
# This case will do 120 iterations until has zero error
# inputs = np.array([0.2])
# initial_weights = np.array([10, 20, 3])
# expected_values = np.array([8, 46, 0.1])
# alpha = 24

# Case 4: MIMO
# This case will do xx iterations until has zero error
inputs = np.array([0.2, 2.3, 1.2])
# initial_weights = np.array([[7.1, 5.7, 2.2], 
#            [1.1, 3.0, 9.1], 
#            [4.4, 9.1, 7.0]])
initial_weights = np.array([[7.1, 1.1, 4.4], 
           [5.7, 3.0, 9.1], 
           [2.2, 5.3, 7.0]])
expected_values = np.array([8, 46, 0.1])
alpha = 0.2

do_learning(inputs, initial_weights, expected_values, alpha)
# Out:
# ########################################
# - Input             :
# [0.2 2.3 1.2]
#
# - initial_weights   :
# [[7.1 1.1 4.4]
#  [5.7 3.  9.1]
#  [2.2 5.3 7. ]]
#
# - expected_value    :
# [ 8.  46.   0.1]
#
# - alpha             :
# 0.2
#
# ########################################
# ==================== Iteration 1
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[7.1 1.1 4.4]
#  [5.7 3.  9.1]
#  [2.2 5.3 7. ]]
#
# - predicted_value   :
# [17.17 13.48 30.21]
#
#
# ----- Calculate Error -----
# - delta             :
# [[  9.17 -32.52  30.11]]
#
# - error             :
# [[  84.0889 1057.5504  906.6121]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[   3.668]
#  [-149.592]
#  [  72.264]]
#
# - weight_adjustment :
# [[  0.7336]
#  [-29.9184]
#  [ 14.4528]]
#
# - new_weight        :
# [[  6.3664   0.3664   3.6664]
#  [ 35.6184  32.9184  39.0184]
#  [-12.2528  -9.1528  -7.4528]]
#
#
# ----- Need Learning -----
# - total_error     :
# 2048.2514
#
# - need_learning     :
# True
#
#
# ==================== Iteration 2
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[  6.3664   0.3664   3.6664]
#  [ 35.6184  32.9184  39.0184]
#  [-12.2528  -9.1528  -7.4528]]
#
# - predicted_value   :
# [68.49224 64.80224 81.53224]
#
#
# ----- Calculate Error -----
# - delta             :
# [[60.49224 18.80224 81.43224]]
#
# - error             :
# [[3659.31110022  353.52422902 6631.20971142]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 24.196896]
#  [ 86.490304]
#  [195.437376]]
#
# - weight_adjustment :
# [[ 4.8393792]
#  [17.2980608]
#  [39.0874752]]
#
# - new_weight        :
# [[  1.5270208  -4.4729792  -1.1729792]
#  [ 18.3203392  15.6203392  21.7203392]
#  [-51.3402752 -48.2402752 -46.5402752]]
#
#
# ----- Need Learning -----
# - total_error     :
# 10644.04504
#
# - need_learning     :
# True
#
#
# ==================== Iteration 3
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[  1.5270208  -4.4729792  -1.1729792]
#  [ 18.3203392  15.6203392  21.7203392]
#  [-51.3402752 -48.2402752 -46.5402752]]
#
# - predicted_value   :
# [-19.16614592 -22.85614592  -6.12614592]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-27.16614592 -68.85614592  -6.22614592]]
#
# - error             :
# [[ 737.99948415 4741.16883096   38.76489302]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -10.86645837]
#  [-316.73827123]
#  [ -14.94275021]]
#
# - weight_adjustment :
# [[ -2.17329167]
#  [-63.34765425]
#  [ -2.98855004]]
#
# - new_weight        :
# [[  3.70031247  -2.29968753   1.00031247]
#  [ 81.66799345  78.96799345  85.06799345]
#  [-48.35172516 -45.25172516 -43.55172516]]
#
#
# ----- Need Learning -----
# - total_error     :
# 5517.93321
#
# - need_learning     :
# True
#
#
# ==================== Iteration 4
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[  3.70031247  -2.29968753   1.00031247]
#  [ 81.66799345  78.96799345  85.06799345]
#  [-48.35172516 -45.25172516 -43.55172516]]
#
# - predicted_value   :
# [130.55437723 126.86437723 143.59437723]
#
#
# ----- Calculate Error -----
# - delta             :
# [[122.55437723  80.86437723 143.49437723]]
#
# - error             :
# [[15019.57537857  6539.04750502 20590.63629702]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 49.02175089]
#  [371.97613526]
#  [344.38650536]]
#
# - weight_adjustment :
# [[ 9.80435018]
#  [74.39522705]
#  [68.87730107]]
#
# - new_weight        :
# [[  -6.1040377   -12.1040377    -8.8040377 ]
#  [   7.27276639    4.57276639   10.67276639]
#  [-117.22902623 -114.12902623 -112.42902623]]
#
#
# ----- Need Learning -----
# - total_error     :
# 42149.25918
#
# - need_learning     :
# True
#
#
# ==================== Iteration 5
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[  -6.1040377   -12.1040377    -8.8040377 ]
#  [   7.27276639    4.57276639   10.67276639]
#  [-117.22902623 -114.12902623 -112.42902623]]
#
# - predicted_value   :
# [-125.16827631 -128.85827631 -112.12827631]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-133.16827631 -174.85827631 -112.22827631]]
#
# - error             :
# [[17733.78981569 30575.41679451 12595.18600377]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -53.26731052]
#  [-804.34807103]
#  [-269.34786315]]
#
# - weight_adjustment :
# [[ -10.6534621 ]
#  [-160.86961421]
#  [ -53.86957263]]
#
# - new_weight        :
# [[  4.5494244  -1.4505756   1.8494244]
#  [168.1423806 165.4423806 171.5423806]
#  [-63.3594536 -60.2594536 -58.5594536]]
#
#
# ----- Need Learning -----
# - total_error     :
# 60904.39261
#
# - need_learning     :
# True
#
#
# ==================== Iteration 6
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[  4.5494244  -1.4505756   1.8494244]
#  [168.1423806 165.4423806 171.5423806]
#  [-63.3594536 -60.2594536 -58.5594536]]
#
# - predicted_value   :
# [311.60601594 307.91601594 324.64601594]
#
#
# ----- Calculate Error -----
# - delta             :
# [[303.60601594 261.91601594 324.54601594]]
#
# - error             :
# [[ 92176.61291464  68599.9994056  105330.11646218]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 121.44240638]
#  [1204.81367332]
#  [ 778.91043825]]
#
# - weight_adjustment :
# [[ 24.28848128]
#  [240.96273466]
#  [155.78208765]]
#
# - new_weight        :
# [[ -19.73905688  -25.73905688  -22.43905688]
#  [ -72.82035406  -75.52035406  -69.42035406]
#  [-219.14154125 -216.04154125 -214.34154125]]
#
#
# ----- Need Learning -----
# - total_error     :
# 266106.72878
#
# - need_learning     :
# True
#
#
# ==================== Iteration 7
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -19.73905688  -25.73905688  -22.43905688]
#  [ -72.82035406  -75.52035406  -69.42035406]
#  [-219.14154125 -216.04154125 -214.34154125]]
#
# - predicted_value   :
# [-434.40447522 -438.09447522 -421.36447522]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-442.40447522 -484.09447522 -421.46447522]]
#
# - error             :
# [[195721.71969876 234347.46094299 177632.30387635]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -176.96179009]
#  [-2226.83458603]
#  [-1011.51474054]]
#
# - weight_adjustment :
# [[ -35.39235802]
#  [-445.36691721]
#  [-202.30294811]]
#
# - new_weight        :
# [[ 15.65330114   9.65330114  12.95330114]
#  [372.54656314 369.84656314 375.94656314]
#  [-16.83859314 -13.73859314 -12.03859314]]
#
#
# ----- Need Learning -----
# - total_error     :
# 607701.48452
#
# - need_learning     :
# True
#
#
# ==================== Iteration 8
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 15.65330114   9.65330114  12.95330114]
#  [372.54656314 369.84656314 375.94656314]
#  [-16.83859314 -13.73859314 -12.03859314]]
#
# - predicted_value   :
# [839.78144368 836.09144368 852.82144368]
#
#
# ----- Calculate Error -----
# - delta             :
# [[831.78144368 790.09144368 852.72144368]]
#
# - error             :
# [[691860.37005642 624244.48938208 727133.86051789]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 332.71257747]
#  [3634.42064094]
#  [2046.53146484]]
#
# - weight_adjustment :
# [[ 66.54251549]
#  [726.88412819]
#  [409.30629297]]
#
# - new_weight        :
# [[ -50.88921435  -56.88921435  -53.58921435]
#  [-354.33756505 -357.03756505 -350.93756505]
#  [-426.14488611 -423.04488611 -421.34488611]]
#
#
# ----- Need Learning -----
# - total_error     :
# 2043238.71996
#
# - need_learning     :
# True
#
#
# ==================== Iteration 9
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -50.88921435  -56.88921435  -53.58921435]
#  [-354.33756505 -357.03756505 -350.93756505]
#  [-426.14488611 -423.04488611 -421.34488611]]
#
# - predicted_value   :
# [-1336.52810581 -1340.21810581 -1323.48810581]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-1344.52810581 -1386.21810581 -1323.58810581]]
#
# - error             :
# [[1807755.82731744 1921600.63688001 1751885.47384605]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -537.81124232]
#  [-6376.60328673]
#  [-3176.61145395]]
#
# - weight_adjustment :
# [[ -107.56224846]
#  [-1275.32065735]
#  [ -635.32229079]]
#
# - new_weight        :
# [[ 56.67303411  50.67303411  53.97303411]
#  [920.9830923  918.2830923  924.3830923 ]
#  [209.17740468 212.27740468 213.97740468]]
#
#
# ----- Need Learning -----
# - total_error     :
# 5481241.93804
#
# - need_learning     :
# True
#
#
# ==================== Iteration 10
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 56.67303411  50.67303411  53.97303411]
#  [920.9830923  918.2830923  924.3830923 ]
#  [209.17740468 212.27740468 213.97740468]]
#
# - predicted_value   :
# [2380.60860473 2376.91860473 2393.64860473]
#
#
# ----- Calculate Error -----
# - delta             :
# [[2372.60860473 2330.91860473 2393.54860473]]
#
# - error             :
# [[5629271.59122119 5433181.54185911 5729074.92318713]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[  949.04344189]
#  [10722.22558174]
#  [ 5744.51665134]]
#
# - weight_adjustment :
# [[ 189.80868838]
#  [2144.44511635]
#  [1148.90333027]]
#
# - new_weight        :
# [[ -133.13565427  -139.13565427  -135.83565427]
#  [-1223.46202405 -1226.16202405 -1220.06202405]
#  [ -939.72592559  -936.62592559  -934.92592559]]
#
#
# ----- Need Learning -----
# - total_error     :
# 16791528.05627
#
# - need_learning     :
# True
#
#
# ==================== Iteration 11
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -133.13565427  -139.13565427  -135.83565427]
#  [-1223.46202405 -1226.16202405 -1220.06202405]
#  [ -939.72592559  -936.62592559  -934.92592559]]
#
# - predicted_value   :
# [-3968.26089687 -3971.95089687 -3955.22089687]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-3976.26089687 -4017.95089687 -3955.32089687]]
#
# - error             :
# [[15810650.7199972  16143929.40967843 15644563.39723618]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -1590.50435875]
#  [-18482.57412561]
#  [ -9492.77015249]]
#
# - weight_adjustment :
# [[ -318.10087175]
#  [-3696.51482512]
#  [-1898.5540305 ]]
#
# - new_weight        :
# [[ 184.96521748  178.96521748  182.26521748]
#  [2473.05280107 2470.35280107 2476.45280107]
#  [ 958.82810491  961.92810491  963.62810491]]
#
#
# ----- Need Learning -----
# - total_error     :
# 47599143.52691
#
# - need_learning     :
# True
#
#
# ==================== Iteration 12
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 184.96521748  178.96521748  182.26521748]
#  [2473.05280107 2470.35280107 2476.45280107]
#  [ 958.82810491  961.92810491  963.62810491]]
#
# - predicted_value   :
# [6875.60821186 6871.91821186 6888.64821186]
#
#
# ----- Calculate Error -----
# - delta             :
# [[6867.60821186 6825.91821186 6888.54821186]]
#
# - error             :
# [[47164042.55158229 46593159.43497756 47452096.46709491]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 2747.04328474]
#  [31399.22377455]
#  [16532.51570846]]
#
# - weight_adjustment :
# [[ 549.40865695]
#  [6279.84475491]
#  [3306.50314169]]
#
# - new_weight        :
# [[ -364.44343946  -370.44343946  -367.14343946]
#  [-3806.79195384 -3809.49195384 -3803.39195384]
#  [-2347.67503678 -2344.57503678 -2342.87503678]]
#
#
# ----- Need Learning -----
# - total_error     :
# 141209298.45365
#
# - need_learning     :
# True
#
#
# ==================== Iteration 13
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -364.44343946  -370.44343946  -367.14343946]
#  [-3806.79195384 -3809.49195384 -3803.39195384]
#  [-2347.67503678 -2344.57503678 -2342.87503678]]
#
# - predicted_value   :
# [-11645.72022585 -11649.41022585 -11632.68022585]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-11653.72022585 -11695.41022585 -11632.78022585]]
#
# - error             :
# [[1.35809195e+08 1.36782620e+08 1.35321576e+08]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -4661.48809034]
#  [-53798.88703893]
#  [-27918.67254205]]
#
# - weight_adjustment :
# [[  -932.29761807]
#  [-10759.77740779]
#  [ -5583.73450841]]
#
# - new_weight        :
# [[ 567.8541786   561.8541786   565.1541786 ]
#  [6952.98545395 6950.28545395 6956.38545395]
#  [3236.05947163 3239.15947163 3240.85947163]]
#
#
# ----- Need Learning -----
# - total_error     :
# 407913391.2365
#
# - need_learning     :
# True
#
#
# ==================== Iteration 14
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 567.8541786   561.8541786   565.1541786 ]
#  [6952.98545395 6950.28545395 6956.38545395]
#  [3236.05947163 3239.15947163 3240.85947163]]
#
# - predicted_value   :
# [19988.70874576 19985.01874576 20001.74874576]
#
#
# ----- Calculate Error -----
# - delta             :
# [[19980.70874576 19939.01874576 20001.64874576]]
#
# - error             :
# [[3.99228722e+08 3.97564469e+08 4.00065953e+08]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 7992.2834983 ]
#  [91719.48623049]
#  [48003.95698982]]
#
# - weight_adjustment :
# [[ 1598.45669966]
#  [18343.8972461 ]
#  [ 9600.79139796]]
#
# - new_weight        :
# [[ -1030.60252106  -1036.60252106  -1033.30252106]
#  [-11390.91179215 -11393.61179215 -11387.51179215]
#  [ -6364.73192634  -6361.63192634  -6359.93192634]]
#
#
# ----- Need Learning -----
# - total_error     :
# 1196859143.07522
#
# - need_learning     :
# True
#
#
# ==================== Iteration 15
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -1030.60252106  -1036.60252106  -1033.30252106]
#  [-11390.91179215 -11393.61179215 -11387.51179215]
#  [ -6364.73192634  -6361.63192634  -6359.93192634]]
#
# - predicted_value   :
# [-34042.89593776 -34046.58593776 -34029.85593776]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-34050.89593776 -34092.58593776 -34029.95593776]]
#
# - error             :
# [[1.15946351e+09 1.16230442e+09 1.15803790e+09]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -13620.3583751 ]
#  [-156825.89531367]
#  [ -81671.89425061]]
#
# - weight_adjustment :
# [[ -2724.07167502]
#  [-31365.17906273]
#  [-16334.37885012]]
#
# - new_weight        :
# [[ 1693.46915396  1687.46915396  1690.76915396]
#  [19974.26727059 19971.56727059 19977.66727059]
#  [ 9969.64692378  9972.74692378  9974.44692378]]
#
#
# ----- Need Learning -----
# - total_error     :
# 3479805831.21262
#
# - need_learning     :
# True
#
#
# ==================== Iteration 16
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 1693.46915396  1687.46915396  1690.76915396]
#  [19974.26727059 19971.56727059 19977.66727059]
#  [ 9969.64692378  9972.74692378  9974.44692378]]
#
# - predicted_value   :
# [58243.08486169 58239.39486169 58256.12486169]
#
#
# ----- Calculate Error -----
# - delta             :
# [[58235.08486169 58193.39486169 58256.02486169]]
#
# - error             :
# [[3.39132511e+09 3.38647121e+09 3.39376443e+09]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 23294.03394467]
#  [267689.61636376]
#  [139814.45966805]]
#
# - weight_adjustment :
# [[ 4658.80678893]
#  [53537.92327275]
#  [27962.89193361]]
#
# - new_weight        :
# [[ -2965.33763497  -2971.33763497  -2968.03763497]
#  [-33563.65600216 -33566.35600216 -33560.25600216]
#  [-17993.24500982 -17990.14500982 -17988.44500982]]
#
#
# ----- Need Learning -----
# - total_error     :
# 10171560747.06122
#
# - need_learning     :
# True
#
#
# ==================== Iteration 17
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -2965.33763497  -2971.33763497  -2968.03763497]
#  [-33563.65600216 -33566.35600216 -33560.25600216]
#  [-17993.24500982 -17990.14500982 -17988.44500982]]
#
# - predicted_value   :
# [-99381.37034376 -99385.06034376 -99368.33034376]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-99389.37034376 -99431.06034376 -99368.43034376]]
#
# - error             :
# [[9.87824694e+09 9.88653576e+09 9.87408495e+09]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -39755.7481375 ]
#  [-457382.87758129]
#  [-238484.23282502]]
#
# - weight_adjustment :
# [[ -7951.1496275 ]
#  [-91476.57551626]
#  [-47696.846565  ]]
#
# - new_weight        :
# [[ 4985.81199253  4979.81199253  4983.11199253]
#  [57912.9195141  57910.2195141  57916.3195141 ]
#  [29703.60155518 29706.70155518 29708.40155518]]
#
#
# ----- Need Learning -----
# - total_error     :
# 29638867647.39591
#
# - need_learning     :
# True
#
#
# ==================== Iteration 18
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 4985.81199253  4979.81199253  4983.11199253]
#  [57912.9195141  57910.2195141  57916.3195141 ]
#  [29703.60155518 29706.70155518 29708.40155518]]
#
# - predicted_value   :
# [169841.19914714 169837.50914714 169854.23914714]
#
#
# ----- Calculate Error -----
# - delta             :
# [[169833.19914714 169791.50914714 169854.13914714]]
#
# - error             :
# [[2.88433155e+10 2.88291566e+10 2.88504286e+10]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 67933.27965886]
#  [781040.94207685]
#  [407649.93395314]]
#
# - weight_adjustment :
# [[ 13586.65593177]
#  [156208.18841537]
#  [ 81529.98679063]]
#
# - new_weight        :
# [[ -8600.84393924  -8606.84393924  -8603.54393924]
#  [-98295.26890127 -98297.96890127 -98291.86890127]
#  [-51826.38523545 -51823.28523545 -51821.58523545]]
#
#
# ----- Need Learning -----
# - total_error     :
# 86522900696.43266
#
# - need_learning     :
# True
#
#
# ==================== Iteration 19
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -8600.84393924  -8606.84393924  -8603.54393924]
#  [-98295.26890127 -98297.96890127 -98291.86890127]
#  [-51826.38523545 -51823.28523545 -51821.58523545]]
#
# - predicted_value   :
# [-289990.94954332 -289994.63954332 -289977.90954332]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-289998.94954332 -290040.63954332 -289978.00954332]]
#
# - error             :
# [[8.40993907e+10 8.41235726e+10 8.40872460e+10]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -115999.57981733]
#  [-1334186.94189926]
#  [ -695947.22290396]]
#
# - weight_adjustment :
# [[ -23199.91596347]
#  [-266837.38837985]
#  [-139189.44458079]]
#
# - new_weight        :
# [[ 14599.07202422  14593.07202422  14596.37202422]
#  [168542.11947858 168539.41947858 168545.51947858]
#  [ 87363.05934534  87366.15934534  87367.85934534]]
#
#
# ----- Need Learning -----
# - total_error     :
# 252310209341.6278
#
# - need_learning     :
# True
#
#
# ==================== Iteration 20
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 14599.07202422  14593.07202422  14596.37202422]
#  [168542.11947858 168539.41947858 168545.51947858]
#  [ 87363.05934534  87366.15934534  87367.85934534]]
#
# - predicted_value   :
# [495402.36041999 495398.67041999 495415.40041999]
#
#
# ----- Calculate Error -----
# - delta             :
# [[495394.36041999 495352.67041999 495415.30041999]]
#
# - error             :
# [[2.45415572e+11 2.45374268e+11 2.45436320e+11]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 198157.74416799]
#  [2278622.28393193]
#  [1188996.72100797]]
#
# - weight_adjustment :
# [[ 39631.5488336 ]
#  [455724.45678639]
#  [237799.34420159]]
#
# - new_weight        :
# [[ -25032.47680937  -25038.47680937  -25035.17680937]
#  [-287182.33730781 -287185.03730781 -287178.93730781]
#  [-150436.28485625 -150433.18485625 -150431.48485625]]
#
#
# ----- Need Learning -----
# - total_error     :
# 736226160318.3618
#
# - need_learning     :
# True
#
#
# ==================== Iteration 21
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -25032.47680937  -25038.47680937  -25035.17680937]
#  [-287182.33730781 -287185.03730781 -287178.93730781]
#  [-150436.28485625 -150433.18485625 -150431.48485625]]
#
# - predicted_value   :
# [-846049.41299734 -846053.10299734 -846036.37299734]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-846057.41299734 -846099.10299734 -846036.47299734]]
#
# - error             :
# [[7.15813146e+11 7.15883692e+11 7.15777714e+11]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -338422.96519893]
#  [-3892055.87378774]
#  [-2030487.5351936 ]]
#
# - weight_adjustment :
# [[ -67684.59303979]
#  [-778411.17475755]
#  [-406097.50703872]]
#
# - new_weight        :
# [[ 42652.11623041  42646.11623041  42649.41623041]
#  [491228.83744974 491226.13744974 491232.23744974]
#  [255661.22218247 255664.32218247 255666.02218247]]
#
#
# ----- Need Learning -----
# - total_error     :
# 2147474551822.4092
#
# - need_learning     :
# True
#
#
# ==================== Iteration 22
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 42652.11623041  42646.11623041  42649.41623041]
#  [491228.83744974 491226.13744974 491232.23744974]
#  [255661.22218247 255664.32218247 255666.02218247]]
#
# - predicted_value   :
# [1445150.21599945 1445146.52599945 1445163.25599945]
#
#
# ----- Calculate Error -----
# - delta             :
# [[1445142.21599945 1445100.52599945 1445163.15599945]]
#
# - error             :
# [[2.08843602e+12 2.08831553e+12 2.08849655e+12]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 578056.88639978]
#  [6647462.41959746]
#  [3468391.57439868]]
#
# - weight_adjustment :
# [[ 115611.37727996]
#  [1329492.48391949]
#  [ 693678.31487974]]
#
# - new_weight        :
# [[ -72959.26104954  -72965.26104954  -72961.96104954]
#  [-838263.64646975 -838266.34646975 -838260.24646975]
#  [-438017.09269726 -438013.99269726 -438012.29269726]]
#
#
# ----- Need Learning -----
# - total_error     :
# 6265248102165.968
#
# - need_learning     :
# True
#
#
# ==================== Iteration 23
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -72959.26104954  -72965.26104954  -72961.96104954]
#  [-838263.64646975 -838266.34646975 -838260.24646975]
#  [-438017.09269726 -438013.99269726 -438012.29269726]]
#
# - predicted_value   :
# [-2468218.75032706 -2468222.44032706 -2468205.71032706]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-2468226.75032706 -2468268.44032706 -2468205.81032706]]
#
# - error             :
# [[6.09214329e+12 6.09234909e+12 6.09203992e+12]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[  -987290.70013082]
#  [-11354034.82550447]
#  [ -5923693.94478494]]
#
# - weight_adjustment :
# [[ -197458.14002616]
#  [-2270806.96510089]
#  [-1184738.78895699]]
#
# - new_weight        :
# [[ 124498.87897662  124492.87897662  124496.17897662]
#  [1432543.31863114 1432540.61863114 1432546.71863114]
#  [ 746721.69625972  746724.79625972  746726.49625972]]
#
#
# ----- Need Learning -----
# - total_error     :
# 18276532306676.887
#
# - need_learning     :
# True
#
#
# ==================== Iteration 24
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 124498.87897662  124492.87897662  124496.17897662]
#  [1432543.31863114 1432540.61863114 1432546.71863114]
#  [ 746721.69625972  746724.79625972  746726.49625972]]
#
# - predicted_value   :
# [4215815.44415861 4215811.75415861 4215828.48415861]
#
#
# ----- Calculate Error -----
# - delta             :
# [[4215807.44415861 4215765.75415861 4215828.38415862]]
#
# - error             :
# [[1.77730324e+13 1.77726809e+13 1.77732090e+13]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 1686322.97766345]
#  [19392522.46912962]
#  [10117988.12198068]]
#
# - weight_adjustment :
# [[ 337264.59553269]
#  [3878504.49382592]
#  [2023597.62439614]]
#
# - new_weight        :
# [[ -212765.71655607  -212771.71655607  -212768.41655607]
#  [-2445961.17519478 -2445963.87519479 -2445957.77519479]
#  [-1276875.92813641 -1276872.82813641 -1276871.12813641]]
#
#
# ----- Need Learning -----
# - total_error     :
# 53318922264837.18
#
# - need_learning     :
# True
#
#
# ==================== Iteration 25
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -212765.71655607  -212771.71655607  -212768.41655607]
#  [-2445961.17519478 -2445963.87519479 -2445957.77519479]
#  [-1276875.92813641 -1276872.82813641 -1276871.12813641]]
#
# - predicted_value   :
# [-7200514.96002291 -7200518.65002291 -7200501.92002291]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-7200522.96002291 -7200564.65002291 -7200502.02002291]]
#
# - error             :
# [[5.18475309e+13 5.18481313e+13 5.18472293e+13]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -2880209.18400916]
#  [-33122597.3901054 ]
#  [-17281204.84805499]]
#
# - weight_adjustment :
# [[ -576041.83680183]
#  [-6624519.47802108]
#  [-3456240.969611  ]]
#
# - new_weight        :
# [[ 363276.12024576  363270.12024576  363273.42024576]
#  [4178558.30282629 4178555.60282629 4178561.70282629]
#  [2179365.04147459 2179368.14147459 2179369.84147459]]
#
#
# ----- Need Learning -----
# - total_error     :
# 155542891517330.72
#
# - need_learning     :
# True
#
#
# ==================== Iteration 26
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 363276.12024576  363270.12024576  363273.42024576]
#  [4178558.30282629 4178555.60282629 4178561.70282629]
#  [2179365.04147459 2179368.14147459 2179369.84147459]]
#
# - predicted_value   :
# [12298577.37031913 12298573.68031913 12298590.41031913]
#
#
# ----- Calculate Error -----
# - delta             :
# [[12298569.37031913 12298527.68031913 12298590.31031913]]
#
# - error             :
# [[1.51254809e+14 1.51253783e+14 1.51255324e+14]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ 4919427.74812765]
#  [56573227.32946801]
#  [29516616.74476592]]
#
# - weight_adjustment :
# [[  983885.54962553]
#  [11314645.4658936 ]
#  [ 5903323.34895318]]
#
# - new_weight        :
# [[ -620609.42937977  -620615.42937977  -620612.12937977]
#  [-7136087.16306731 -7136089.86306731 -7136083.76306731]
#  [-3723958.3074786  -3723955.2074786  -3723953.5074786 ]]
#
#
# ----- Need Learning -----
# - total_error     :
# 453763915281203.6
#
# - need_learning     :
# True
#
#
# ==================== Iteration 27
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -620609.42937977  -620615.42937977  -620612.12937977]
#  [-7136087.16306731 -7136089.86306731 -7136083.76306731]
#  [-3723958.3074786  -3723955.2074786  -3723953.5074786 ]]
#
# - predicted_value   :
# [-21005872.32990508 -21005876.01990508 -21005859.28990508]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-21005880.32990508 -21005922.01990508 -21005859.38990508]]
#
# - error             :
# [[4.41247008e+14 4.41248760e+14 4.41246129e+14]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[ -8402352.13196203]
#  [-96627241.29156336]
#  [-50414062.53577219]]
#
# - weight_adjustment :
# [[ -1680470.42639241]
#  [-19325448.25831267]
#  [-10082812.50715444]]
#
# - new_weight        :
# [[ 1059860.99701264  1059854.99701264  1059858.29701264]
#  [12189361.09524536 12189358.39524536 12189364.49524536]
#  [ 6358854.19967584  6358857.29967584  6358858.99967584]]
#
#
# ----- Need Learning -----
# - total_error     :
# 1323741897049089.5
#
# - need_learning     :
# True
#
#
# ==================== Iteration 28
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 1059860.99701264  1059854.99701264  1059858.29701264]
#  [12189361.09524536 12189358.39524536 12189364.49524536]
#  [ 6358854.19967584  6358857.29967584  6358858.99967584]]
#
# - predicted_value   :
# [35878127.75807787 35878124.06807787 35878140.79807787]
#
#
# ----- Calculate Error -----
# - delta             :
# [[35878119.75807787 35878078.06807787 35878140.69807786]]
#
# - error             :
# [[1.28723948e+15 1.28723649e+15 1.28724098e+15]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[1.43512479e+07]
#  [1.65039159e+08]
#  [8.61075377e+07]]
#
# - weight_adjustment :
# [[ 2870249.58064623]
#  [33007831.82263164]
#  [17221507.53507737]]
#
# - new_weight        :
# [[ -1810388.58363359  -1810394.58363359  -1810391.28363359]
#  [-20818470.72738628 -20818473.42738628 -20818467.32738628]
#  [-10862653.33540153 -10862650.23540153 -10862648.53540153]]
#
#
# ----- Need Learning -----
# - total_error     :
# 3861716943185139.0
#
# - need_learning     :
# True
#
#
# ==================== Iteration 29
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -1810388.58363359  -1810394.58363359  -1810391.28363359]
#  [-20818470.72738628 -20818473.42738628 -20818467.32738628]
#  [-10862653.33540153 -10862650.23540153 -10862648.53540153]]
#
# - predicted_value   :
# [-61279744.39219701 -61279748.082197   -61279731.352197  ]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-61279752.39219701 -61279794.082197   -61279731.452197  ]]
#
# - error             :
# [[3.75520805e+15 3.75521316e+15 3.75520549e+15]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-2.45119010e+07]
#  [-2.81887053e+08]
#  [-1.47071355e+08]]
#
# - weight_adjustment :
# [[ -4902380.19137576]
#  [-56377410.55562124]
#  [-29414271.09705456]]
#
# - new_weight        :
# [[ 3091991.60774217  3091985.60774217  3091988.90774217]
#  [35558939.82823496 35558937.12823495 35558943.22823496]
#  [18551617.76165303 18551620.86165303 18551622.56165303]]
#
#
# ----- Need Learning -----
# - total_error     :
# 1.1265626702858822e+16
#
# - need_learning     :
# True
#
#
# ==================== Iteration 30
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ 3091991.60774217  3091985.60774217  3091988.90774217]
#  [35558939.82823496 35558937.12823495 35558943.22823496]
#  [18551617.76165303 18551620.86165303 18551622.56165303]]
#
# - predicted_value   :
# [1.04665901e+08 1.04665898e+08 1.04665914e+08]
#
#
# ----- Calculate Error -----
# - delta             :
# [[1.04665893e+08 1.04665852e+08 1.04665914e+08]]
#
# - error             :
# [[1.09549492e+16 1.09549405e+16 1.09549536e+16]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[4.18663573e+07]
#  [4.81462917e+08]
#  [2.51198194e+08]]
#
# - weight_adjustment :
# [[ 8373271.4592378 ]
#  [96292583.42643465]
#  [50239638.80662679]]
#
# - new_weight        :
# [[ -5281279.85149563  -5281285.85149563  -5281282.55149563]
#  [-60733643.5981997  -60733646.2981997  -60733640.19819969]
#  [-31688021.04497376 -31688017.94497376 -31688016.24497376]]
#
#
# ----- Need Learning -----
# - total_error     :
# 3.2864843279845544e+16
#
# - need_learning     :
# True
#
#
# ==================== Iteration 31
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[ -5281279.85149563  -5281285.85149563  -5281282.55149563]
#  [-60733643.5981997  -60733646.2981997  -60733640.19819969]
#  [-31688021.04497376 -31688017.94497376 -31688016.24497376]]
#
# - predicted_value   :
# [-1.78769262e+08 -1.78769265e+08 -1.78769248e+08]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-1.78769270e+08 -1.78769311e+08 -1.78769249e+08]]
#
# - error             :
# [[3.19584517e+16 3.19584666e+16 3.19584442e+16]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-7.15077078e+07]
#  [-8.22338831e+08]
#  [-4.29046197e+08]]
#
# - weight_adjustment :
# [[-1.43015416e+07]
#  [-1.64467766e+08]
#  [-8.58092393e+07]]
#
# - new_weight        :
# [[9.02026171e+06 9.02025571e+06 9.02025901e+06]
#  [1.03734123e+08 1.03734120e+08 1.03734126e+08]
#  [5.41212183e+07 5.41212214e+07 5.41212231e+07]]
#
#
# ----- Need Learning -----
# - total_error     :
# 9.587536257175389e+16
#
# - need_learning     :
# True
#
#
# ==================== Iteration 32
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[9.02026171e+06 9.02025571e+06 9.02025901e+06]
#  [1.03734123e+08 1.03734120e+08 1.03734126e+08]
#  [5.41212183e+07 5.41212214e+07 5.41212231e+07]]
#
# - predicted_value   :
# [3.05337996e+08 3.05337993e+08 3.05338010e+08]
#
#
# ----- Calculate Error -----
# - delta             :
# [[3.05337988e+08 3.05337947e+08 3.05338009e+08]]
#
# - error             :
# [[9.32312872e+16 9.32312617e+16 9.32313000e+16]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[1.22135195e+08]
#  [1.40455456e+09]
#  [7.32811223e+08]]
#
# - weight_adjustment :
# [[2.44270391e+07]
#  [2.80910911e+08]
#  [1.46562245e+08]]
#
# - new_weight        :
# [[-1.54067774e+07 -1.54067834e+07 -1.54067801e+07]
#  [-1.77176788e+08 -1.77176791e+08 -1.77176785e+08]
#  [-9.24410262e+07 -9.24410231e+07 -9.24410214e+07]]
#
#
# ----- Need Learning -----
# - total_error     :
# 2.7969384892036912e+17
#
# - need_learning     :
# True
#
#
# ==================== Iteration 33
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-1.54067774e+07 -1.54067834e+07 -1.54067801e+07]
#  [-1.77176788e+08 -1.77176791e+08 -1.77176785e+08]
#  [-9.24410262e+07 -9.24410231e+07 -9.24410214e+07]]
#
# - predicted_value   :
# [-5.21517200e+08 -5.21517204e+08 -5.21517187e+08]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-5.21517208e+08 -5.21517250e+08 -5.21517187e+08]]
#
# - error             :
# [[2.71980198e+17 2.71980242e+17 2.71980177e+17]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-2.08606883e+08]
#  [-2.39897935e+09]
#  [-1.25164125e+09]]
#
# - weight_adjustment :
# [[-4.17213767e+07]
#  [-4.79795870e+08]
#  [-2.50328250e+08]]
#
# - new_weight        :
# [[2.63145993e+07 2.63145933e+07 2.63145966e+07]
#  [3.02619082e+08 3.02619079e+08 3.02619085e+08]
#  [1.57887224e+08 1.57887227e+08 1.57887228e+08]]
#
#
# ----- Need Learning -----
# - total_error     :
# 8.159406167903564e+17
#
# - need_learning     :
# True
#
#
# ==================== Iteration 34
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[2.63145993e+07 2.63145933e+07 2.63145966e+07]
#  [3.02619082e+08 3.02619079e+08 3.02619085e+08]
#  [1.57887224e+08 1.57887227e+08 1.57887228e+08]]
#
# - predicted_value   :
# [8.90751476e+08 8.90751472e+08 8.90751489e+08]
#
#
# ----- Calculate Error -----
# - delta             :
# [[8.90751468e+08 8.90751426e+08 8.90751489e+08]]
#
# - error             :
# [[7.93438177e+17 7.93438103e+17 7.93438214e+17]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[3.56300587e+08]
#  [4.09745656e+09]
#  [2.13780357e+09]]
#
# - weight_adjustment :
# [[7.12601174e+07]
#  [8.19491312e+08]
#  [4.27560715e+08]]
#
# - new_weight        :
# [[-4.49455181e+07 -4.49455241e+07 -4.49455208e+07]
#  [-5.16872230e+08 -5.16872233e+08 -5.16872227e+08]
#  [-2.69673491e+08 -2.69673488e+08 -2.69673486e+08]]
#
#
# ----- Need Learning -----
# - total_error     :
# 2.3803144944047857e+18
#
# - need_learning     :
# True
#
#
# ==================== Iteration 35
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-4.49455181e+07 -4.49455241e+07 -4.49455208e+07]
#  [-5.16872230e+08 -5.16872233e+08 -5.16872227e+08]
#  [-2.69673491e+08 -2.69673488e+08 -2.69673486e+08]]
#
# - predicted_value   :
# [-1.52140342e+09 -1.52140343e+09 -1.52140341e+09]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-1.52140343e+09 -1.52140347e+09 -1.52140341e+09]]
#
# - error             :
# [[2.31466840e+18 2.31466853e+18 2.31466833e+18]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-6.08561372e+08]
#  [-6.99845597e+09]
#  [-3.65136818e+09]]
#
# - weight_adjustment :
# [[-1.21712274e+08]
#  [-1.39969119e+09]
#  [-7.30273637e+08]]
#
# - new_weight        :
# [[7.67667563e+07 7.67667503e+07 7.67667536e+07]
#  [8.82818964e+08 8.82818961e+08 8.82818968e+08]
#  [4.60600146e+08 4.60600149e+08 4.60600151e+08]]
#
#
# ----- Need Learning -----
# - total_error     :
# 6.944005259012405e+18
#
# - need_learning     :
# True
#
#
# ==================== Iteration 36
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[7.67667563e+07 7.67667503e+07 7.67667536e+07]
#  [8.82818964e+08 8.82818961e+08 8.82818968e+08]
#  [4.60600146e+08 4.60600149e+08 4.60600151e+08]]
#
# - predicted_value   :
# [2.59855714e+09 2.59855714e+09 2.59855716e+09]
#
#
# ----- Calculate Error -----
# - delta             :
# [[2.59855714e+09 2.59855709e+09 2.59855716e+09]]
#
# - error             :
# [[6.75249919e+18 6.75249897e+18 6.75249930e+18]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[1.03942285e+09]
#  [1.19533626e+10]
#  [6.23653718e+09]]
#
# - weight_adjustment :
# [[2.07884571e+08]
#  [2.39067253e+09]
#  [1.24730744e+09]]
#
# - new_weight        :
# [[-1.31117815e+08 -1.31117821e+08 -1.31117817e+08]
#  [-1.50785356e+09 -1.50785356e+09 -1.50785356e+09]
#  [-7.86707289e+08 -7.86707286e+08 -7.86707285e+08]]
#
#
# ----- Need Learning -----
# - total_error     :
# 2.025749745324897e+19
#
# - need_learning     :
# True
#
#
# ==================== Iteration 37
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-1.31117815e+08 -1.31117821e+08 -1.31117817e+08]
#  [-1.50785356e+09 -1.50785356e+09 -1.50785356e+09]
#  [-7.86707289e+08 -7.86707286e+08 -7.86707285e+08]]
#
# - predicted_value   :
# [-4.43833550e+09 -4.43833551e+09 -4.43833549e+09]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-4.43833551e+09 -4.43833555e+09 -4.43833549e+09]]
#
# - error             :
# [[1.96988221e+19 1.96988225e+19 1.96988219e+19]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-1.77533420e+09]
#  [-2.04163435e+10]
#  [-1.06520052e+10]]
#
# - weight_adjustment :
# [[-3.55066841e+08]
#  [-4.08326871e+09]
#  [-2.13040104e+09]]
#
# - new_weight        :
# [[2.23949026e+08 2.23949020e+08 2.23949024e+08]
#  [2.57541515e+09 2.57541514e+09 2.57541515e+09]
#  [1.34369375e+09 1.34369375e+09 1.34369375e+09]]
#
#
# ----- Need Learning -----
# - total_error     :
# 5.909646652124591e+19
#
# - need_learning     :
# True
#
#
# ==================== Iteration 38
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[2.23949026e+08 2.23949020e+08 2.23949024e+08]
#  [2.57541515e+09 2.57541514e+09 2.57541515e+09]
#  [1.34369375e+09 1.34369375e+09 1.34369375e+09]]
#
# - predicted_value   :
# [7.58067714e+09 7.58067713e+09 7.58067715e+09]
#
#
# ----- Calculate Error -----
# - delta             :
# [[7.58067713e+09 7.58067709e+09 7.58067715e+09]]
#
# - error             :
# [[5.74666657e+19 5.74666651e+19 5.74666661e+19]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[3.03227085e+09]
#  [3.48711146e+10]
#  [1.81936252e+10]]
#
# - weight_adjustment :
# [[6.06454170e+08]
#  [6.97422292e+09]
#  [3.63872503e+09]]
#
# - new_weight        :
# [[-3.82505144e+08 -3.82505150e+08 -3.82505147e+08]
#  [-4.39880777e+09 -4.39880778e+09 -4.39880777e+09]
#  [-2.29503129e+09 -2.29503128e+09 -2.29503128e+09]]
#
#
# ----- Need Learning -----
# - total_error     :
# 1.7239999692152478e+20
#
# - need_learning     :
# True
#
#
# ==================== Iteration 39
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-3.82505144e+08 -3.82505150e+08 -3.82505147e+08]
#  [-4.39880777e+09 -4.39880778e+09 -4.39880777e+09]
#  [-2.29503129e+09 -2.29503128e+09 -2.29503128e+09]]
#
# - predicted_value   :
# [-1.29477965e+10 -1.29477965e+10 -1.29477964e+10]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-1.29477965e+10 -1.29477965e+10 -1.29477964e+10]]
#
# - error             :
# [[1.67645433e+20 1.67645434e+20 1.67645433e+20]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-5.17911858e+09]
#  [-5.95598639e+10]
#  [-3.10747115e+10]]
#
# - weight_adjustment :
# [[-1.03582372e+09]
#  [-1.19119728e+10]
#  [-6.21494229e+09]]
#
# - new_weight        :
# [[6.53318573e+08 6.53318567e+08 6.53318570e+08]
#  [7.51316501e+09 7.51316501e+09 7.51316501e+09]
#  [3.91991101e+09 3.91991101e+09 3.91991101e+09]]
#
#
# ----- Need Learning -----
# - total_error     :
# 5.029363001581685e+20
#
# - need_learning     :
# True
#
#
# ==================== Iteration 40
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[6.53318573e+08 6.53318567e+08 6.53318570e+08]
#  [7.51316501e+09 7.51316501e+09 7.51316501e+09]
#  [3.91991101e+09 3.91991101e+09 3.91991101e+09]]
#
# - predicted_value   :
# [2.21148364e+10 2.21148364e+10 2.21148365e+10]
#
#
# ----- Calculate Error -----
# - delta             :
# [[2.21148364e+10 2.21148364e+10 2.21148365e+10]]
#
# - error             :
# [[4.89065990e+20 4.89065989e+20 4.89065991e+20]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[8.84593457e+09]
#  [1.01728247e+11]
#  [5.30756075e+10]]
#
# - weight_adjustment :
# [[1.76918691e+09]
#  [2.03456495e+10]
#  [1.06151215e+10]]
#
# - new_weight        :
# [[-1.11586834e+09 -1.11586835e+09 -1.11586834e+09]
#  [-1.28324845e+10 -1.28324845e+10 -1.28324845e+10]
#  [-6.69521049e+09 -6.69521049e+09 -6.69521049e+09]]
#
#
# ----- Need Learning -----
# - total_error     :
# 1.4671979703641894e+21
#
# - need_learning     :
# True
#
#
# ==================== Iteration 41
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-1.11586834e+09 -1.11586835e+09 -1.11586834e+09]
#  [-1.28324845e+10 -1.28324845e+10 -1.28324845e+10]
#  [-6.69521049e+09 -6.69521049e+09 -6.69521049e+09]]
#
# - predicted_value   :
# [-3.77721405e+10 -3.77721405e+10 -3.77721405e+10]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-3.77721406e+10 -3.77721406e+10 -3.77721405e+10]]
#
# - error             :
# [[1.4267346e+21 1.4267346e+21 1.4267346e+21]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-1.51088562e+10]
#  [-1.73751847e+11]
#  [-9.06531373e+10]]
#
# - weight_adjustment :
# [[-3.02177124e+09]
#  [-3.47503693e+10]
#  [-1.81306275e+10]]
#
# - new_weight        :
# [[1.90590290e+09 1.90590290e+09 1.90590290e+09]
#  [2.19178849e+10 2.19178849e+10 2.19178849e+10]
#  [1.14354170e+10 1.14354170e+10 1.14354170e+10]]
#
#
# ----- Need Learning -----
# - total_error     :
# 4.2802038068022896e+21
#
# - need_learning     :
# True
#
#
# ==================== Iteration 42
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[1.90590290e+09 1.90590290e+09 1.90590290e+09]
#  [2.19178849e+10 2.19178849e+10 2.19178849e+10]
#  [1.14354170e+10 1.14354170e+10 1.14354170e+10]]
#
# - predicted_value   :
# [6.45148161e+10 6.45148161e+10 6.45148162e+10]
#
#
# ----- Calculate Error -----
# - delta             :
# [[6.45148161e+10 6.45148161e+10 6.45148162e+10]]
#
# - error             :
# [[4.1621615e+21 4.1621615e+21 4.1621615e+21]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[2.58059265e+10]
#  [2.96768154e+11]
#  [1.54835559e+11]]
#
# - weight_adjustment :
# [[5.16118529e+09]
#  [5.93536308e+10]
#  [3.09671118e+10]]
#
# - new_weight        :
# [[-3.25528239e+09 -3.25528239e+09 -3.25528239e+09]
#  [-3.74357459e+10 -3.74357459e+10 -3.74357459e+10]
#  [-1.95316948e+10 -1.95316948e+10 -1.95316948e+10]]
#
#
# ----- Need Learning -----
# - total_error     :
# 1.2486484500475562e+22
#
# - need_learning     :
# True
#
#
# ==================== Iteration 43
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-3.25528239e+09 -3.25528239e+09 -3.25528239e+09]
#  [-3.74357459e+10 -3.74357459e+10 -3.74357459e+10]
#  [-1.95316948e+10 -1.95316948e+10 -1.95316948e+10]]
#
# - predicted_value   :
# [-1.10191306e+11 -1.10191306e+11 -1.10191306e+11]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-1.10191306e+11 -1.10191306e+11 -1.10191306e+11]]
#
# - error             :
# [[1.21421239e+22 1.21421239e+22 1.21421239e+22]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-4.40765224e+10]
#  [-5.06880007e+11]
#  [-2.64459134e+11]]
#
# - weight_adjustment :
# [[-8.81530447e+09]
#  [-1.01376001e+11]
#  [-5.28918268e+10]]
#
# - new_weight        :
# [[5.56002208e+09 5.56002208e+09 5.56002208e+09]
#  [6.39402555e+10 6.39402555e+10 6.39402555e+10]
#  [3.33601320e+10 3.33601320e+10 3.33601320e+10]]
#
#
# ----- Need Learning -----
# - total_error     :
# 3.64263716818294e+22
#
# - need_learning     :
# True
#
#
# ==================== Iteration 44
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[5.56002208e+09 5.56002208e+09 5.56002208e+09]
#  [6.39402555e+10 6.39402555e+10 6.39402555e+10]
#  [3.33601320e+10 3.33601320e+10 3.33601320e+10]]
#
# - predicted_value   :
# [1.88206751e+11 1.88206751e+11 1.88206751e+11]
#
#
# ----- Calculate Error -----
# - delta             :
# [[1.88206751e+11 1.88206750e+11 1.88206751e+11]]
#
# - error             :
# [[3.54217809e+22 3.54217809e+22 3.54217810e+22]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[7.52827002e+10]
#  [8.65751052e+11]
#  [4.51696201e+11]]
#
# - weight_adjustment :
# [[1.50565400e+10]
#  [1.73150210e+11]
#  [9.03392403e+10]]
#
# - new_weight        :
# [[-9.49651796e+09 -9.49651797e+09 -9.49651796e+09]
#  [-1.09209955e+11 -1.09209955e+11 -1.09209955e+11]
#  [-5.69791082e+10 -5.69791082e+10 -5.69791082e+10]]
#
#
# ----- Need Learning -----
# - total_error     :
# 1.0626534282286616e+23
#
# - need_learning     :
# True
#
#
# ==================== Iteration 45
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-9.49651796e+09 -9.49651797e+09 -9.49651796e+09]
#  [-1.09209955e+11 -1.09209955e+11 -1.09209955e+11]
#  [-5.69791082e+10 -5.69791082e+10 -5.69791082e+10]]
#
# - predicted_value   :
# [-3.2145713e+11 -3.2145713e+11 -3.2145713e+11]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-3.2145713e+11 -3.2145713e+11 -3.2145713e+11]]
#
# - error             :
# [[1.03334686e+23 1.03334686e+23 1.03334686e+23]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-1.28582852e+11]
#  [-1.47870280e+12]
#  [-7.71497112e+11]]
#
# - weight_adjustment :
# ...
#  [3.36354993e+229 3.36354993e+229 3.36354993e+229]]
#
# - predicted_value   :
# [1.89760275e+230 1.89760275e+230 1.89760275e+230]
#
#
# ----- Calculate Error -----
# - delta             :
# [[1.89760275e+230 1.89760275e+230 1.89760275e+230]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[7.59041100e+229]
#  [8.72897265e+230]
#  [4.55424660e+230]]
#
# - weight_adjustment :
# [[1.51808220e+229]
#  [1.74579453e+230]
#  [9.10849320e+229]]
#
# - new_weight        :
# [[-9.57490545e+228 -9.57490545e+228 -9.57490545e+228]
#  [-1.10111413e+230 -1.10111413e+230 -1.10111413e+230]
#  [-5.74494327e+229 -5.74494327e+229 -5.74494327e+229]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 987
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-9.57490545e+228 -9.57490545e+228 -9.57490545e+228]
#  [-1.10111413e+230 -1.10111413e+230 -1.10111413e+230]
#  [-5.74494327e+229 -5.74494327e+229 -5.74494327e+229]]
#
# - predicted_value   :
# [-3.2411055e+230 -3.2411055e+230 -3.2411055e+230]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-3.2411055e+230 -3.2411055e+230 -3.2411055e+230]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-1.29644220e+230]
#  [-1.49090853e+231]
#  [-7.77865319e+230]]
#
# - weight_adjustment :
# [[-2.59288440e+229]
#  [-2.98181706e+230]
#  [-1.55573064e+230]]
#
# - new_weight        :
# [[1.63539385e+229 1.63539385e+229 1.63539385e+229]
#  [1.88070293e+230 1.88070293e+230 1.88070293e+230]
#  [9.81236311e+229 9.81236311e+229 9.81236311e+229]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 988
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[1.63539385e+229 1.63539385e+229 1.63539385e+229]
#  [1.88070293e+230 1.88070293e+230 1.88070293e+230]
#  [9.81236311e+229 9.81236311e+229 9.81236311e+229]]
#
# - predicted_value   :
# [5.53580819e+230 5.53580819e+230 5.53580819e+230]
#
#
# ----- Calculate Error -----
# - delta             :
# [[5.53580819e+230 5.53580819e+230 5.53580819e+230]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[2.21432327e+230]
#  [2.54647177e+231]
#  [1.32859396e+231]]
#
# - weight_adjustment :
# [[4.42864655e+229]
#  [5.09294353e+230]
#  [2.65718793e+230]]
#
# - new_weight        :
# [[-2.79325270e+229 -2.79325270e+229 -2.79325270e+229]
#  [-3.21224060e+230 -3.21224060e+230 -3.21224060e+230]
#  [-1.67595162e+230 -1.67595162e+230 -1.67595162e+230]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 989
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-2.79325270e+229 -2.79325270e+229 -2.79325270e+229]
#  [-3.21224060e+230 -3.21224060e+230 -3.21224060e+230]
#  [-1.67595162e+230 -1.67595162e+230 -1.67595162e+230]]
#
# - predicted_value   :
# [-9.45516038e+230 -9.45516038e+230 -9.45516038e+230]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-9.45516038e+230 -9.45516038e+230 -9.45516038e+230]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-3.78206415e+230]
#  [-4.34937378e+231]
#  [-2.26923849e+231]]
#
# - weight_adjustment :
# [[-7.56412831e+229]
#  [-8.69874755e+230]
#  [-4.53847698e+230]]
#
# - new_weight        :
# [[4.77087561e+229 4.77087561e+229 4.77087561e+229]
#  [5.48650695e+230 5.48650695e+230 5.48650695e+230]
#  [2.86252537e+230 2.86252537e+230 2.86252537e+230]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 990
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[4.77087561e+229 4.77087561e+229 4.77087561e+229]
#  [5.48650695e+230 5.48650695e+230 5.48650695e+230]
#  [2.86252537e+230 2.86252537e+230 2.86252537e+230]]
#
# - predicted_value   :
# [1.61494139e+231 1.61494139e+231 1.61494139e+231]
#
#
# ----- Calculate Error -----
# - delta             :
# [[1.61494139e+231 1.61494139e+231 1.61494139e+231]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[6.45976557e+230]
#  [7.42873041e+231]
#  [3.87585934e+231]]
#
# - weight_adjustment :
# [[1.29195311e+230]
#  [1.48574608e+231]
#  [7.75171869e+230]]
#
# - new_weight        :
# [[-8.14865554e+229 -8.14865554e+229 -8.14865554e+229]
#  [-9.37095387e+230 -9.37095387e+230 -9.37095387e+230]
#  [-4.88919332e+230 -4.88919332e+230 -4.88919332e+230]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 991
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-8.14865554e+229 -8.14865554e+229 -8.14865554e+229]
#  [-9.37095387e+230 -9.37095387e+230 -9.37095387e+230]
#  [-4.88919332e+230 -4.88919332e+230 -4.88919332e+230]]
#
# - predicted_value   :
# [-2.7583199e+231 -2.7583199e+231 -2.7583199e+231]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-2.7583199e+231 -2.7583199e+231 -2.7583199e+231]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-1.10332796e+231]
#  [-1.26882715e+232]
#  [-6.61996776e+231]]
#
# - weight_adjustment :
# [[-2.20665592e+230]
#  [-2.53765431e+231]
#  [-1.32399355e+231]]
#
# - new_weight        :
# [[1.39179037e+230 1.39179037e+230 1.39179037e+230]
#  [1.60055892e+231 1.60055892e+231 1.60055892e+231]
#  [8.35074220e+230 8.35074220e+230 8.35074220e+230]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 992
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[1.39179037e+230 1.39179037e+230 1.39179037e+230]
#  [1.60055892e+231 1.60055892e+231 1.60055892e+231]
#  [8.35074220e+230 8.35074220e+230 8.35074220e+230]]
#
# - predicted_value   :
# [4.71121039e+231 4.71121039e+231 4.71121039e+231]
#
#
# ----- Calculate Error -----
# - delta             :
# [[4.71121039e+231 4.71121039e+231 4.71121039e+231]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[1.88448416e+231]
#  [2.16715678e+232]
#  [1.13069049e+232]]
#
# - weight_adjustment :
# [[3.76896831e+230]
#  [4.33431356e+231]
#  [2.26138099e+231]]
#
# - new_weight        :
# [[-2.37717795e+230 -2.37717795e+230 -2.37717795e+230]
#  [-2.73375464e+231 -2.73375464e+231 -2.73375464e+231]
#  [-1.42630677e+231 -1.42630677e+231 -1.42630677e+231]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 993
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-2.37717795e+230 -2.37717795e+230 -2.37717795e+230]
#  [-2.73375464e+231 -2.73375464e+231 -2.73375464e+231]
#  [-1.42630677e+231 -1.42630677e+231 -1.42630677e+231]]
#
# - predicted_value   :
# [-8.04674735e+231 -8.04674735e+231 -8.04674735e+231]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-8.04674735e+231 -8.04674735e+231 -8.04674735e+231]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-3.21869894e+231]
#  [-3.70150378e+232]
#  [-1.93121936e+232]]
#
# - weight_adjustment :
# [[-6.43739788e+230]
#  [-7.40300756e+231]
#  [-3.86243873e+231]]
#
# - new_weight        :
# [[4.06021993e+230 4.06021993e+230 4.06021993e+230]
#  [4.66925292e+231 4.66925292e+231 4.66925292e+231]
#  [2.43613196e+231 2.43613196e+231 2.43613196e+231]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 994
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[4.06021993e+230 4.06021993e+230 4.06021993e+230]
#  [4.66925292e+231 4.66925292e+231 4.66925292e+231]
#  [2.43613196e+231 2.43613196e+231 2.43613196e+231]]
#
# - predicted_value   :
# [1.37438445e+232 1.37438445e+232 1.37438445e+232]
#
#
# ----- Calculate Error -----
# - delta             :
# [[1.37438445e+232 1.37438445e+232 1.37438445e+232]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[5.49753779e+231]
#  [6.32216845e+232]
#  [3.29852267e+232]]
#
# - weight_adjustment :
# [[1.09950756e+231]
#  [1.26443369e+232]
#  [6.59704534e+231]]
#
# - new_weight        :
# [[-6.93485564e+230 -6.93485564e+230 -6.93485564e+230]
#  [-7.97508399e+231 -7.97508399e+231 -7.97508399e+231]
#  [-4.16091338e+231 -4.16091338e+231 -4.16091338e+231]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 995
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-6.93485564e+230 -6.93485564e+230 -6.93485564e+230]
#  [-7.97508399e+231 -7.97508399e+231 -7.97508399e+231]
#  [-4.16091338e+231 -4.16091338e+231 -4.16091338e+231]]
#
# - predicted_value   :
# [-2.34744863e+232 -2.34744863e+232 -2.34744863e+232]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-2.34744863e+232 -2.34744863e+232 -2.34744863e+232]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-9.38979454e+231]
#  [-1.07982637e+233]
#  [-5.63387672e+232]]
#
# - weight_adjustment :
# [[-1.87795891e+231]
#  [-2.15965274e+232]
#  [-1.12677534e+232]]
#
# - new_weight        :
# [[1.18447334e+231 1.18447334e+231 1.18447334e+231]
#  [1.36214435e+232 1.36214435e+232 1.36214435e+232]
#  [7.10684006e+231 7.10684006e+231 7.10684006e+231]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 996
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[1.18447334e+231 1.18447334e+231 1.18447334e+231]
#  [1.36214435e+232 1.36214435e+232 1.36214435e+232]
#  [7.10684006e+231 7.10684006e+231 7.10684006e+231]]
#
# - predicted_value   :
# [4.00944227e+232 4.00944227e+232 4.00944227e+232]
#
#
# ----- Calculate Error -----
# - delta             :
# [[4.00944227e+232 4.00944227e+232 4.00944227e+232]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[1.60377691e+232]
#  [1.84434344e+233]
#  [9.62266144e+232]]
#
# - weight_adjustment :
# [[3.20755381e+231]
#  [3.68868689e+232]
#  [1.92453229e+232]]
#
# - new_weight        :
# [[-2.02308047e+231 -2.02308047e+231 -2.02308047e+231]
#  [-2.32654254e+232 -2.32654254e+232 -2.32654254e+232]
#  [-1.21384828e+232 -1.21384828e+232 -1.21384828e+232]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 997
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-2.02308047e+231 -2.02308047e+231 -2.02308047e+231]
#  [-2.32654254e+232 -2.32654254e+232 -2.32654254e+232]
#  [-1.21384828e+232 -1.21384828e+232 -1.21384828e+232]]
#
# - predicted_value   :
# [-6.84812739e+232 -6.84812739e+232 -6.84812739e+232]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-6.84812739e+232 -6.84812739e+232 -6.84812739e+232]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-2.73925096e+232]
#  [-3.15013860e+233]
#  [-1.64355057e+233]]
#
# - weight_adjustment :
# [[-5.47850192e+231]
#  [-6.30027720e+232]
#  [-3.28710115e+232]]
#
# - new_weight        :
# [[3.45542144e+231 3.45542144e+231 3.45542144e+231]
#  [3.97373466e+232 3.97373466e+232 3.97373466e+232]
#  [2.07325287e+232 2.07325287e+232 2.07325287e+232]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 998
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[3.45542144e+231 3.45542144e+231 3.45542144e+231]
#  [3.97373466e+232 3.97373466e+232 3.97373466e+232]
#  [2.07325287e+232 2.07325287e+232 2.07325287e+232]]
#
# - predicted_value   :
# [1.16966016e+233 1.16966016e+233 1.16966016e+233]
#
#
# ----- Calculate Error -----
# - delta             :
# [[1.16966016e+233 1.16966016e+233 1.16966016e+233]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[4.67864064e+232]
#  [5.38043673e+233]
#  [2.80718438e+233]]
#
# - weight_adjustment :
# [[9.35728127e+231]
#  [1.07608735e+233]
#  [5.61436876e+232]]
#
# - new_weight        :
# [[-5.90185983e+231 -5.90185983e+231 -5.90185983e+231]
#  [-6.78713880e+232 -6.78713880e+232 -6.78713880e+232]
#  [-3.54111590e+232 -3.54111590e+232 -3.54111590e+232]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 999
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[-5.90185983e+231 -5.90185983e+231 -5.90185983e+231]
#  [-6.78713880e+232 -6.78713880e+232 -6.78713880e+232]
#  [-3.54111590e+232 -3.54111590e+232 -3.54111590e+232]]
#
# - predicted_value   :
# [-1.99777955e+233 -1.99777955e+233 -1.99777955e+233]
#
#
# ----- Calculate Error -----
# - delta             :
# [[-1.99777955e+233 -1.99777955e+233 -1.99777955e+233]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[-7.99111821e+232]
#  [-9.18978594e+233]
#  [-4.79467092e+233]]
#
# - weight_adjustment :
# [[-1.59822364e+232]
#  [-1.83795719e+233]
#  [-9.58934185e+232]]
#
# - new_weight        :
# [[1.00803766e+232 1.00803766e+232 1.00803766e+232]
#  [1.15924331e+233 1.15924331e+233 1.15924331e+233]
#  [6.04822595e+232 6.04822595e+232 6.04822595e+232]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
#
#
# ==================== Iteration 1000
# ----- Setup -----
# - Input             :
# [0.2 2.3 1.2]
#
# - expected_value    :
# [[ 8.  46.   0.1]]
#
# - alpha             :
# 0.2
#
#
# ----- NN Prediction -----
# - weight            :
# [[1.00803766e+232 1.00803766e+232 1.00803766e+232]
#  [1.15924331e+233 1.15924331e+233 1.15924331e+233]
#  [6.04822595e+232 6.04822595e+232 6.04822595e+232]]
#
# - predicted_value   :
# [3.41220747e+233 3.41220747e+233 3.41220747e+233]
#
#
# ----- Calculate Error -----
# - delta             :
# [[3.41220747e+233 3.41220747e+233 3.41220747e+233]]
#
# - error             :
# [[inf inf inf]]
#
#
# ----- Weight Adjustment -----
# - error_derivative  :
# [[1.36488299e+233]
#  [1.56961544e+234]
#  [8.18929794e+233]]
#
# - weight_adjustment :
# [[2.72976598e+232]
#  [3.13923088e+233]
#  [1.63785959e+233]]
#
# - new_weight        :
# [[-1.72172832e+232 -1.72172832e+232 -1.72172832e+232]
#  [-1.97998757e+233 -1.97998757e+233 -1.97998757e+233]
#  [-1.03303699e+233 -1.03303699e+233 -1.03303699e+233]]
#
#
# ----- Need Learning -----
# - total_error     :
# inf
#
# - need_learning     :
# True
# C:\Users\anton\AppData\Local\Temp\ipykernel_4584\4120727665.py:63: RuntimeWarning: overflow encountered in multiply
#   total_error = round(np.sum(errors), 5)
# z:\10__Python\3.12.4\Lib\site-packages\numpy\_core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# C:\Users\anton\AppData\Local\Temp\ipykernel_4584\4120727665.py:44: RuntimeWarning: overflow encountered in square
#   errors = deltas ** 2
